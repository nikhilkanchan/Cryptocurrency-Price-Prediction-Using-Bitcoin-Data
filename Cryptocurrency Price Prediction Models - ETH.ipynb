# %% [markdown]
# ### <font color = blue> FORECASTING THE PRICE OF MAJOR CRYPTOCURRENCIES BASED ON HISTORICAL PRICE OF BITCOIN  </font>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing data for all the cryptocurrencies to be analysed.
# - btc ==> Bitcoin
# - doge ==> Dogecoin
# - eth ==> Ethereum
# - ltc ==> Litecoin
# - usdt ==> Tether
# - usdc ==> USD Coin
# - xmr ==> Monero

# %%
btc = pd.read_csv('BTC-USD.csv')
doge = pd.read_csv('DOGE-USD.csv')
eth = pd.read_csv('ETH-USD.csv')
ltc = pd.read_csv('LTC-USD.csv')
usdt = pd.read_csv('USDT-USD.csv')
usdc = pd.read_csv('USDc-USD.csv')
xmr = pd.read_csv('XMR-USD.csv')

# %%
btc.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  17-09-2014  465.864014  468.174011  452.421997  457.334015  457.334015
# 1  18-09-2014  456.859985  456.859985  413.104004  424.440002  424.440002
# 2  19-09-2014  424.102997  427.834991  384.532013  394.795990  394.795990
# 3  20-09-2014  394.673004  423.295990  389.882996  408.903992  408.903992
# 4  21-09-2014  408.084991  412.425995  393.181000  398.821014  398.821014
#
#        Volume
# 0  21056800.0
# 1  34483200.0
# 2  37919700.0
# 3  36863600.0
# 4  26580100.0

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935 entries, 0 to 2934
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2935 non-null   object
#  1   Open       2935 non-null   float64
#  2   High       2935 non-null   float64
#  3   Low        2935 non-null   float64
#  4   Close      2935 non-null   float64
#  5   Adj Close  2935 non-null   float64
#  6   Volume     2935 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 160.6+ KB

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1786 non-null   object
#  1   Open       1786 non-null   float64
#  2   High       1786 non-null   float64
#  3   Low        1786 non-null   float64
#  4   Close      1786 non-null   float64
#  5   Adj Close  1786 non-null   float64
#  6   Volume     1786 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 97.8+ KB

# %%
# ethereum heatmap
plt.title('Heatmap - BTC Data')
sns.heatmap(btc.corr(), annot=True)
plt.show()

# %%
doge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1786 non-null   object
#  1   Open       1786 non-null   float64
#  2   High       1786 non-null   float64
#  3   Low        1786 non-null   float64
#  4   Close      1786 non-null   float64
#  5   Adj Close  1786 non-null   float64
#  6   Volume     1786 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 97.8+ KB

# %%
ltc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935 entries, 0 to 2934
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2935 non-null   object
#  1   Open       2935 non-null   float64
#  2   High       2935 non-null   float64
#  3   Low        2935 non-null   float64
#  4   Close      2935 non-null   float64
#  5   Adj Close  2935 non-null   float64
#  6   Volume     2935 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 160.6+ KB

# %%
usdt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1786 non-null   object
#  1   Open       1786 non-null   float64
#  2   High       1786 non-null   float64
#  3   Low        1786 non-null   float64
#  4   Close      1786 non-null   float64
#  5   Adj Close  1786 non-null   float64
#  6   Volume     1786 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 97.8+ KB

# %%
usdc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1453 non-null   object
#  1   Open       1453 non-null   float64
#  2   High       1453 non-null   float64
#  3   Low        1453 non-null   float64
#  4   Close      1453 non-null   float64
#  5   Adj Close  1453 non-null   float64
#  6   Volume     1453 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 79.6+ KB

# %%
xmr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1786 non-null   object
#  1   Open       1786 non-null   float64
#  2   High       1786 non-null   float64
#  3   Low        1786 non-null   float64
#  4   Close      1786 non-null   float64
#  5   Adj Close  1786 non-null   float64
#  6   Volume     1786 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 97.8+ KB

# %% [markdown]
# Here we can conclude that there are no missing values in the entire dataset.

# %%
btc['Date'] = pd.to_datetime(btc['Date'], format='%d-%m-%Y')
doge['Date'] = pd.to_datetime(doge['Date'], format='%d-%m-%Y')
eth['Date'] = pd.to_datetime(eth['Date'], format='%Y-%m-%d')
ltc['Date'] = pd.to_datetime(ltc['Date'], format='%Y-%m-%d')
usdt['Date'] = pd.to_datetime(usdt['Date'], format='%Y-%m-%d')
usdc['Date'] = pd.to_datetime(usdc['Date'], format='%Y-%m-%d')
xmr['Date'] = pd.to_datetime(xmr['Date'], format='%Y-%m-%d')

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935 entries, 0 to 2934
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2935 non-null   datetime64[ns]
#  1   Open       2935 non-null   float64
#  2   High       2935 non-null   float64
#  3   Low        2935 non-null   float64
#  4   Close      2935 non-null   float64
#  5   Adj Close  2935 non-null   float64
#  6   Volume     2935 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 160.6 KB

# %%
# 'Close' and 'Adj Close' columns have same values, hence dropping one of them
btc.drop(['Adj Close'], axis=1, inplace=True)
doge.drop(['Adj Close'], axis=1, inplace=True)
eth.drop(['Adj Close'], axis=1, inplace=True)
ltc.drop(['Adj Close'], axis=1, inplace=True)
usdt.drop(['Adj Close'], axis=1, inplace=True)
usdc.drop(['Adj Close'], axis=1, inplace=True)
xmr.drop(['Adj Close'], axis=1, inplace=True)

# %% [markdown]
# #### Lets analyze the data for outliers. First the Volume field for all the currencies.
# 1. First plot a line plot to see Volume against time and see if there is something unsual
# 2. Box-Plot for detailed analysis of volume outliers
# 3. Histogram to check the distribution of volume

# %%
# Line Plot
plt.figure(figsize=(16,8))

plt.subplot(4,2,1)
sns.lineplot(x="Date", y="Volume", data=btc)
plt.title("Bitcoin Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,2)
sns.lineplot(x="Date", y="Volume", data=doge)
plt.title("Dogecoin Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,3)
sns.lineplot(x="Date", y="Volume", data=eth)
plt.title("Ethereum Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,4)
sns.lineplot(x="Date", y="Volume", data=ltc)
plt.title("Lite Coin Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,5)
sns.lineplot(x="Date", y="Volume", data=usdt)
plt.title("Tether Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,6)
sns.lineplot(x="Date", y="Volume", data=usdc)
plt.title("USDC Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,7)
sns.lineplot(x="Date", y="Volume", data=xmr)
plt.title("Monero Volume chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.tight_layout(pad=2.0)
plt.show()

# %%
# Box Plot
plt.figure(figsize=(16,8))

plt.subplot(4,2,1)
sns.boxplot(x=btc['Volume'],whis=2.5)
plt.title("Bitcoin Volume Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,2)
sns.boxplot(x=doge['Volume'],whis=2.5)
plt.title("Dogecoin Volume Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,3)
sns.boxplot(x=eth['Volume'],whis=2.5)
plt.title("Ethereum Volume Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,4)
sns.boxplot(x=ltc['Volume'],whis=2.5)
plt.title("Litecoin Volume Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,5)
sns.boxplot(x=usdt['Volume'],whis=2.5)
plt.title("Tether Vol Price Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,6)
sns.boxplot(x=usdc['Volume'],whis=2.5)
plt.title("USDC Vol Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,7)
sns.boxplot(x=xmr['Volume'],whis=2.5)
plt.title("Monero Vol Box Plot", color = 'Red', fontweight = 100)

plt.tight_layout(pad=2.0)
plt.show()

# %%
fig = btc['Volume'].hist(figsize = (16,4))
plt.title("Bitcoin Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = doge['Volume'].hist(figsize = (16,4))
plt.title("Dogecoin Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = eth['Volume'].hist(figsize = (16,4))
plt.title("Ethereum Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = ltc['Volume'].hist(figsize = (16,4))
plt.title("Litecoin Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = usdt['Volume'].hist(figsize = (16,4))
plt.title("Tether Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = usdc['Volume'].hist(figsize = (16,4))
plt.title("USDC Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = xmr['Volume'].hist(figsize = (16,4))
plt.title("Monero Volume Distribution", color = 'Red', fontweight = 100)
plt.show()

# %% [markdown]
# #### Lets analyze the price field for all the currencies. We will consider the Closing price.
# 1. First plot a line plot to see Close price against time and see if there is something unsual
# 2. Box-Plot for detailed analysis of close price outliers
# 3. Histogram to check the distribution of close price

# %%
# Line Plot
plt.figure(figsize=(16,8))

plt.subplot(4,2,1)
sns.lineplot(x="Date", y="Close", data=btc)
plt.title("Bitcoin Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,2)
sns.lineplot(x="Date", y="Close", data=doge)
plt.title("Dogecoin Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,3)
sns.lineplot(x="Date", y="Close", data=eth)
plt.title("Ethereum Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,4)
sns.lineplot(x="Date", y="Close", data=ltc)
plt.title("Lite Coin Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,5)
sns.lineplot(x="Date", y="Close", data=usdt)
plt.title("Tether Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,6)
sns.lineplot(x="Date", y="Close", data=usdc)
plt.title("USDC Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.subplot(4,2,7)
sns.lineplot(x="Date", y="Close", data=xmr)
plt.title("Monero Close chart", color = 'Red', fontweight = 100)
plt.xticks(color = 'White')

plt.tight_layout(pad=2.0)
plt.show()

# %%
# Box Plot
plt.figure(figsize=(16,8))

plt.subplot(4,2,1)
sns.boxplot(x=btc['Close'],whis=2.5)
plt.title("Bitcoin Close Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,2)
sns.boxplot(x=doge['Close'],whis=2.5)
plt.title("Dogecoin Close Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,3)
sns.boxplot(x=eth['Close'],whis=2.5)
plt.title("Ethereum Close Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,4)
sns.boxplot(x=ltc['Close'],whis=2.5)
plt.title("Litecoin Close Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,5)
sns.boxplot(x=usdt['Close'],whis=2.5)
plt.title("Tether Vol Price Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,6)
sns.boxplot(x=usdc['Close'],whis=2.5)
plt.title("USDC Vol Box Plot", color = 'Red', fontweight = 100)

plt.subplot(4,2,7)
sns.boxplot(x=xmr['Close'],whis=2.5)
plt.title("Monero Vol Box Plot", color = 'Red', fontweight = 100)

plt.tight_layout(pad=2.0)
plt.show()

# %%
fig = btc['Close'].hist(figsize = (16,4))
plt.title("Bitcoin Close Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = doge['Close'].hist(figsize = (16,4))
plt.title("Dogecoin Close Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = eth['Close'].hist(figsize = (16,4))
plt.title("Ethereum Close Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = ltc['Close'].hist(figsize = (16,4))
plt.title("Litecoin Close Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = usdt['Close'].hist(figsize = (16,4))
plt.title("Tether Close Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = usdc['Close'].hist(figsize = (16,4))
plt.title("USDC Close Distribution", color = 'Red', fontweight = 100)
plt.show()

fig = xmr['Close'].hist(figsize = (16,4))
plt.title("Monero Close Distribution", color = 'Red', fontweight = 100)
plt.show()

# %%
btc_plt = btc[1149:]

# %%
btc.head()
# Out:
#         Date        Open        High         Low       Close      Volume
# 0 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800.0
# 1 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200.0
# 2 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700.0
# 3 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600.0
# 4 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100.0

# %%
# Relationship b/w BTC and ETH CLose price
plt.scatter(btc_plt.Close, eth.Close)
plt.show()

# %%
fig, ax = plt.subplots()

doge1, = ax.plot(doge.Date, doge.Close)
doge1.set_label("DOGE")

ltc1, = ax.plot(ltc.Date, ltc.Close)
ltc1.set_label("LTC")

usdt1, = ax.plot(usdt.Date, usdt.Close)
usdt1.set_label("USDT")

usdc1, = ax.plot(usdc.Date, usdc.Close)
usdc1.set_label("USDC")

xmr1, = ax.plot(xmr.Date, xmr.Close)
xmr1.set_label("XMR")


plt.legend()

plt.legend(bbox_to_anchor=(1.31,0.4))

plt.show()

# %% [markdown]
# Lets proceed with Ethereum for now. It has no volume or price outliers.
# We will start with a base models which will only have a univariate ARMA and ARIMA model that will provide us a baseline or the starting point

# %% [markdown]
# #### Feature Engineering

# %%
btc = btc[['Date', 'Close','Open', 'High', 'Low', 'Volume']]
crypto = btc.merge(eth,on='Date')
crypto.rename(columns={"Open_x": "Open_btc",
                   "High_x": "High_btc",
                   "Low_x": "Low_btc",
                   "Close_x": "Close_btc",
                   "Volume_x": "Volume_btc",
                   "Open_y": "Open_eth",
                   "High_y": "High_eth",
                   "Low_y": "Low_eth",
                   "Close_y": "Close_eth",
                   "Volume_y": "Volume_eth"
                   }, inplace=True)
crypto.head()
# Out:
#         Date    Close_btc     Open_btc     High_btc      Low_btc  \
# 0 2017-11-09  7143.580078  7446.830078  7446.830078  7101.520020
# 1 2017-11-10  6618.140137  7173.729980  7312.000000  6436.870117
# 2 2017-11-11  6357.600098  6618.609863  6873.149902  6204.220215
# 3 2017-11-12  5950.069824  6295.450195  6625.049805  5519.009766
# 4 2017-11-13  6559.490234  5938.250000  6811.189941  5844.290039
#
#      Volume_btc    Open_eth    High_eth     Low_eth   Close_eth  Volume_eth
# 0  3.226250e+09  308.644989  329.451996  307.056000  320.884003   893249984
# 1  5.208250e+09  320.670990  324.717987  294.541992  299.252991   885985984
# 2  4.908680e+09  298.585999  319.453003  298.191986  314.681000   842300992
# 3  8.957350e+09  314.690002  319.153015  298.513000  307.907990  1613479936
# 4  6.263250e+09  307.024994  328.415009  307.024994  316.716003  1041889984

# %%
crypto
# Out:
#            Date     Close_btc      Open_btc      High_btc       Low_btc  \
# 0    2017-11-09   7143.580078   7446.830078   7446.830078   7101.520020
# 1    2017-11-10   6618.140137   7173.729980   7312.000000   6436.870117
# 2    2017-11-11   6357.600098   6618.609863   6873.149902   6204.220215
# 3    2017-11-12   5950.069824   6295.450195   6625.049805   5519.009766
# 4    2017-11-13   6559.490234   5938.250000   6811.189941   5844.290039
# ...         ...           ...           ...           ...           ...
# 1781 2022-09-25  18802.097660  18936.310550  19134.732420  18696.468750
# 1782 2022-09-26  19222.671880  18803.900390  19274.873050  18721.285160
# 1783 2022-09-27  19110.546880  19221.839840  20338.455080  18915.667970
# 1784 2022-09-28  19426.720700  19104.621090  19688.343750  18553.296880
# 1785 2022-09-29  19433.087890  19436.218750  19589.265630  19311.470700
#
#         Volume_btc     Open_eth     High_eth      Low_eth    Close_eth  \
# 0     3.226250e+09   308.644989   329.451996   307.056000   320.884003
# 1     5.208250e+09   320.670990   324.717987   294.541992   299.252991
# 2     4.908680e+09   298.585999   319.453003   298.191986   314.681000
# 3     8.957350e+09   314.690002   319.153015   298.513000   307.907990
# 4     6.263250e+09   307.024994   328.415009   307.024994   316.716003
# ...            ...          ...          ...          ...          ...
# 1781  2.335997e+10  1317.938477  1333.371338  1275.627686  1294.216797
# 1782  4.414880e+10  1294.386108  1335.526367  1282.049316  1335.320190
# 1783  5.857144e+10  1335.337036  1396.891479  1308.991455  1330.127686
# 1784  5.307130e+10  1329.541382  1351.964478  1267.869263  1337.410889
# 1785  4.738118e+10  1339.188599  1347.720703  1317.508301  1334.941406
#
#        Volume_eth
# 0       893249984
# 1       885985984
# 2       842300992
# 3      1613479936
# 4      1041889984
# ...           ...
# 1781  11802651633
# 1782  16034549271
# 1783  17870598937
# 1784  18994979566
# 1785  15698216960
#
# [1786 rows x 11 columns]

# %%
# Using TA library to extract new features
from ta import add_all_ta_features
from ta.utils import dropna

# %%
add_all_ta_features(crypto, 
                    open='Open_btc', 
                    high='High_btc', 
                    low='Low_btc', 
                    close='Close_btc', 
                    volume='Volume_btc', 
                    fillna=True)
crypto.head()
# Out:
#         Date    Close_btc     Open_btc     High_btc      Low_btc  \
# 0 2017-11-09  7143.580078  7446.830078  7446.830078  7101.520020
# 1 2017-11-10  6618.140137  7173.729980  7312.000000  6436.870117
# 2 2017-11-11  6357.600098  6618.609863  6873.149902  6204.220215
# 3 2017-11-12  5950.069824  6295.450195  6625.049805  5519.009766
# 4 2017-11-13  6559.490234  5938.250000  6811.189941  5844.290039
#
#      Volume_btc    Open_eth    High_eth     Low_eth   Close_eth  ...  \
# 0  3.226250e+09  308.644989  329.451996  307.056000  320.884003  ...
# 1  5.208250e+09  320.670990  324.717987  294.541992  299.252991  ...
# 2  4.908680e+09  298.585999  319.453003  298.191986  314.681000  ...
# 3  8.957350e+09  314.690002  319.153015  298.513000  307.907990  ...
# 4  6.263250e+09  307.024994  328.415009  307.024994  316.716003  ...
#
#    momentum_ppo  momentum_ppo_signal  momentum_ppo_hist  momentum_pvo  \
# 0      0.000000             0.000000           0.000000      0.000000
# 1     -0.589971            -0.117994          -0.471977      4.687377
# 2     -1.348517            -0.364099          -0.984419      7.350066
# 3     -2.412867            -0.773853          -1.639015     16.784287
# 4     -2.520161            -1.123114          -1.397047     18.239058
#
#    momentum_pvo_signal  momentum_pvo_hist  momentum_kama  others_dr  \
# 0             0.000000           0.000000    7143.580078 -64.665181
# 1             0.937475           3.749901    6938.297352  -7.355415
# 2             2.219993           5.130073    6680.905833  -3.936756
# 3             5.132852          11.651435    6361.957670  -6.410128
# 4             7.754093          10.484964    6431.511341  10.242240
#
#    others_dlr  others_cr
# 0    0.000000   0.000000
# 1   -7.639968  -7.355415
# 2   -4.016342 -11.002606
# 3   -6.624801 -16.707453
# 4    9.750994  -8.176430
#
# [5 rows x 97 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from feature_engine.selection import (
    DropDuplicateFeatures,
    DropConstantFeatures,
    DropCorrelatedFeatures,
    SmartCorrelatedSelection,
    SelectByShuffling,
    SelectBySingleFeaturePerformance,
    RecursiveFeatureElimination,
)

# %%
y = crypto['Close_eth']
X = crypto.drop('Close_eth', axis=1)

# %%
X.shape
# Out:
# (1786, 96)

# %%
constant = DropConstantFeatures(tol=0.500)
constant.fit(X)
# Out:
# DropConstantFeatures(tol=0.5)

# %%
len(constant.features_to_drop_)
# Out:
# 6

# %%
constant.features_to_drop_
# Out:
# ['volatility_bbhi',
#  'volatility_bbli',
#  'volatility_kchi',
#  'volatility_kcli',
#  'trend_psar_up_indicator',
#  'trend_psar_down_indicator']

# %%
X.drop(constant.features_to_drop_, axis=1, inplace=True)
X.shape
# Out:
# (1786, 90)

# %%
duplicates = DropDuplicateFeatures()
duplicates.fit(X)
# Out:
# DropDuplicateFeatures()

# %%
len(duplicates.features_to_drop_)
# Out:
# 0

# %%
correlated = DropCorrelatedFeatures(variables=None, method='pearson', threshold=0.7)
correlated.fit(X)
# Out:
# DropCorrelatedFeatures(threshold=0.7)

# %%
len(correlated.features_to_drop_)
# Out:
# 64

# %%
l = list(correlated.features_to_drop_)

# %%
X.drop(l, axis=1, inplace=True)
X.shape
# Out:
# (1786, 26)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1786 entries, 0 to 1785
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1786 non-null   datetime64[ns]
#  1   Close_btc          1786 non-null   float64
#  2   Volume_btc         1786 non-null   float64
#  3   volume_cmf         1786 non-null   float64
#  4   volume_fi          1786 non-null   float64
#  5   volume_em          1786 non-null   float64
#  6   volume_sma_em      1786 non-null   float64
#  7   volume_vpt         1786 non-null   float64
#  8   volume_mfi         1786 non-null   float64
#  9   volume_nvi         1786 non-null   float64
#  10  volatility_bbw     1786 non-null   float64
#  11  volatility_kcp     1786 non-null   float64
#  12  volatility_ui      1786 non-null   float64
#  13  trend_macd_signal  1786 non-null   float64
#  14  trend_trix         1786 non-null   float64
#  15  trend_mass_index   1786 non-null   float64
#  16  trend_dpo          1786 non-null   float64
#  17  trend_kst_sig      1786 non-null   float64
#  18  trend_kst_diff     1786 non-null   float64
#  19  trend_stc          1786 non-null   float64
#  20  trend_adx          1786 non-null   float64
#  21  trend_aroon_up     1786 non-null   float64
#  22  trend_aroon_down   1786 non-null   float64
#  23  momentum_pvo       1786 non-null   float64
#  24  momentum_pvo_hist  1786 non-null   float64
#  25  others_dr          1786 non-null   float64
# dtypes: datetime64[ns](1), float64(25)
# memory usage: 376.7 KB

# %%
smart_correlated = SmartCorrelatedSelection(variables=None, 
                                            method='pearson', 
                                            threshold=0.7, 
                                            missing_values='ignore', 
                                            selection_method='missing_values', 
                                            estimator=None, 
                                            scoring='roc_auc', 
                                            cv=3)
smart_correlated.fit(X)
# Out:
# SmartCorrelatedSelection(threshold=0.7)

# %%
smart_correlated.correlated_feature_sets_
# Out:
# []

# %%
len(smart_correlated.features_to_drop_)
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
SBS_model = SelectByShuffling(estimator=linear_model, scoring="r2", cv=3)
SBS = SBS_model.fit_transform(X, y)

# %%
SBS_model.initial_model_performance_
# Out:
# -12.640585580083481

# %%
SBS_model.performance_drifts_
# Out:
# {'Close_btc': 22.45108215820232,
#  'Volume_btc': -0.3776138817090686,
#  'volume_cmf': -0.046806115750394284,
#  'volume_fi': 0.001935074667635206,
#  'volume_em': -0.0004357849598459751,
#  'volume_sma_em': 0.07674425488387726,
#  'volume_vpt': -0.008178610950233534,
#  'volume_mfi': 0.11122883175359988,
#  'volume_nvi': -2.248884167684123,
#  'volatility_bbw': 0.11737525556686457,
#  'volatility_kcp': 0.024580991409806074,
#  'volatility_ui': 0.9907880249398406,
#  'trend_macd_signal': 0.32602852541658756,
#  'trend_trix': 2.46468410841039,
#  'trend_mass_index': 1.128610181219889,
#  'trend_dpo': 0.19463858423233837,
#  'trend_kst_sig': 0.6699624721075335,
#  'trend_kst_diff': 0.07506659558450757,
#  'trend_stc': -0.09052607973139892,
#  'trend_adx': -0.0027984320606293522,
#  'trend_aroon_up': 0.033022841977336626,
#  'trend_aroon_down': -0.0002969594064534675,
#  'momentum_pvo': -0.07034314314058321,
#  'momentum_pvo_hist': -0.003804545599694009,
#  'others_dr': 0.04595329054490982}

# %%
sorted_sbs_var = {var: val for var, val in sorted(SBS_model.performance_drifts_.items(), key=lambda item: item[1])}

# %%
sorted_sbs_var
# Out:
# {'volume_nvi': -2.248884167684123,
#  'Volume_btc': -0.3776138817090686,
#  'trend_stc': -0.09052607973139892,
#  'momentum_pvo': -0.07034314314058321,
#  'volume_cmf': -0.046806115750394284,
#  'volume_vpt': -0.008178610950233534,
#  'momentum_pvo_hist': -0.003804545599694009,
#  'trend_adx': -0.0027984320606293522,
#  'volume_em': -0.0004357849598459751,
#  'trend_aroon_down': -0.0002969594064534675,
#  'volume_fi': 0.001935074667635206,
#  'volatility_kcp': 0.024580991409806074,
#  'trend_aroon_up': 0.033022841977336626,
#  'others_dr': 0.04595329054490982,
#  'trend_kst_diff': 0.07506659558450757,
#  'volume_sma_em': 0.07674425488387726,
#  'volume_mfi': 0.11122883175359988,
#  'volatility_bbw': 0.11737525556686457,
#  'trend_dpo': 0.19463858423233837,
#  'trend_macd_signal': 0.32602852541658756,
#  'trend_kst_sig': 0.6699624721075335,
#  'volatility_ui': 0.9907880249398406,
#  'trend_mass_index': 1.128610181219889,
#  'trend_trix': 2.46468410841039,
#  'Close_btc': 22.45108215820232}

# %%
sfp = SelectBySingleFeaturePerformance(estimator=LinearRegression(), scoring="r2", cv=3, threshold=0.01)
sfp.fit(X, y)
# Out:
# SelectBySingleFeaturePerformance(estimator=LinearRegression(), scoring='r2',
#                                  threshold=0.01)

# %%
sorted_sfp_var = {var: val for var, val in sorted(sfp.feature_performance_.items(), key=lambda item: item[1])}
sorted_sfp_var
# Out:
# {'volume_nvi': -115.17124562770557,
#  'trend_trix': -12.67576691584855,
#  'volume_cmf': -12.451436363500642,
#  'trend_kst_sig': -12.295818097258254,
#  'Volume_btc': -12.242088879103683,
#  'volatility_bbw': -12.195977189061963,
#  'trend_mass_index': -12.154333278458656,
#  'volatility_ui': -11.9856800327442,
#  'trend_macd_signal': -11.956181684761882,
#  'trend_dpo': -11.866317379614443,
#  'trend_aroon_up': -11.826211191377121,
#  'trend_aroon_down': -11.808063079248543,
#  'others_dr': -11.795521476324382,
#  'trend_adx': -11.794950630535432,
#  'momentum_pvo_hist': -11.792387050046877,
#  'trend_kst_diff': -11.784007969205845,
#  'volume_em': -11.76806912365995,
#  'volatility_kcp': -11.76484024654412,
#  'volume_vpt': -11.763796180381505,
#  'trend_stc': -11.751793022584245,
#  'volume_mfi': -11.751286153707175,
#  'momentum_pvo': -11.74885304101784,
#  'volume_fi': -11.728130946680523,
#  'volume_sma_em': -11.626344776588141,
#  'Close_btc': -0.8293985094734667}

# %%
lr = LinearRegression()
lr_model = RecursiveFeatureElimination(estimator=lr, scoring="r2", cv=3)
lr_model.fit_transform(X, y)
lr_model.initial_model_performance_
# Out:
# -12.640585580083481

# %%
lr_model.performance_drifts_
# Out:
# {'volume_fi': 0.5985256013990323,
#  'Volume_btc': -1.2641420956095981,
#  'volume_vpt': -0.21631998641255912,
#  'volume_em': -0.019465327296522617,
#  'trend_dpo': -2.393945488694582,
#  'volume_sma_em': -0.553215297971736,
#  'Close_btc': 142.56404388624674,
#  'trend_macd_signal': 3.3283095966662195,
#  'trend_aroon_down': 0.04088756290993345,
#  'trend_kst_sig': 1.6610076191514622,
#  'trend_stc': -0.8480243716598563,
#  'trend_kst_diff': 3.8407239386302683,
#  'trend_aroon_up': 0.026226202709368707,
#  'volume_nvi': 1.6238564034741492,
#  'others_dr': 0.013044357418356967,
#  'trend_adx': 0.25507766596816683,
#  'volume_mfi': -0.799252025073474,
#  'volatility_bbw': 0.12907833853367645,
#  'momentum_pvo_hist': 0.017847986709281116,
#  'momentum_pvo': 0.0379704305135391,
#  'volatility_ui': 1.0368981110376625,
#  'trend_mass_index': -0.021296175233402437,
#  'volatility_kcp': -0.1746483824571028,
#  'trend_trix': -0.01376569966872232,
#  'volume_cmf': 0.5230747300973686}

# %%
sorted_lr_var = {var: val for var, val in sorted(lr_model.performance_drifts_.items(), key=lambda item: item[1])}
sorted_lr_var
# Out:
# {'trend_dpo': -2.393945488694582,
#  'Volume_btc': -1.2641420956095981,
#  'trend_stc': -0.8480243716598563,
#  'volume_mfi': -0.799252025073474,
#  'volume_sma_em': -0.553215297971736,
#  'volume_vpt': -0.21631998641255912,
#  'volatility_kcp': -0.1746483824571028,
#  'trend_mass_index': -0.021296175233402437,
#  'volume_em': -0.019465327296522617,
#  'trend_trix': -0.01376569966872232,
#  'others_dr': 0.013044357418356967,
#  'momentum_pvo_hist': 0.017847986709281116,
#  'trend_aroon_up': 0.026226202709368707,
#  'momentum_pvo': 0.0379704305135391,
#  'trend_aroon_down': 0.04088756290993345,
#  'volatility_bbw': 0.12907833853367645,
#  'trend_adx': 0.25507766596816683,
#  'volume_cmf': 0.5230747300973686,
#  'volume_fi': 0.5985256013990323,
#  'volatility_ui': 1.0368981110376625,
#  'volume_nvi': 1.6238564034741492,
#  'trend_kst_sig': 1.6610076191514622,
#  'trend_macd_signal': 3.3283095966662195,
#  'trend_kst_diff': 3.8407239386302683,
#  'Close_btc': 142.56404388624674}

# %%
X.shape
# Out:
# (1786, 26)

# %%
# With aim to have only 10 variables in the final dataset, dropping the 16 least impacting variables based on the above models
X.drop(['trend_trix',
        'Volume_btc',
        'momentum_pvo',
        'trend_stc',
        'volume_cmf',
        'trend_adx',
        'momentum_pvo_hist',
        'volume_vpt',
        'trend_aroon_down',
        'volatility_kcp',
        'volume_em',
        'trend_aroon_up',
        'others_dr',
        'volume_sma_em',
        'volatility_bbw',
        'volume_mfi'
        ], axis=1, inplace=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1786 entries, 0 to 1785
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1786 non-null   datetime64[ns]
#  1   Close_btc          1786 non-null   float64
#  2   volume_fi          1786 non-null   float64
#  3   volume_nvi         1786 non-null   float64
#  4   volatility_ui      1786 non-null   float64
#  5   trend_macd_signal  1786 non-null   float64
#  6   trend_mass_index   1786 non-null   float64
#  7   trend_dpo          1786 non-null   float64
#  8   trend_kst_sig      1786 non-null   float64
#  9   trend_kst_diff     1786 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 153.5 KB

# %% [markdown]
# ### Defining the Base Model for Ethereum

# %% [markdown]
# The ARMA models are univariate models, hence having the date fields as Index and closing price as the field to be predicted

# %%
base = eth[['Date', 'Close']]
base = base.set_index('Date')
base.head()
# Out:
#                  Close
# Date
# 2017-11-09  320.884003
# 2017-11-10  299.252991
# 2017-11-11  314.681000
# 2017-11-12  307.907990
# 2017-11-13  316.716003

# %% [markdown]
# #### Check for seasionality using Additive & Multiplicative decompositions
# #### Additive seasonal decomposition

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 12, 8
decomposition = sm.tsa.seasonal_decompose(base.Close, model='additive') # additive seasonal index
fig = decomposition.plot()
plt.show()

# %% [markdown]
# #### Multiplicative seasonal decomposition

# %%
decomposition = sm.tsa.seasonal_decompose(base.Close, model='multiplicative') # multiplicative seasonal index
fig = decomposition.plot()
plt.show()

# %% [markdown]
# On analyzing the models, we can conclude that there is high fluctuation in closing price, but a pattern is present to indicate patterns repeating 52 times a year. Hence, we will use seasionality as 52 when required.

# %% [markdown]
# #### Train-Test split

# %%
base.shape
# Out:
# (1786, 1)

# %%
train_len = 1700
train = base[0:train_len]
test = base[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 1)
# test :  (86, 1)

# %% [markdown]
# #### Kwiatkowski-Phillips-Schmidt-Shin (KPSS) test for stationarity

# %%
from statsmodels.tsa.stattools import kpss
kpss_test = kpss(base['Close'])

print('KPSS Statistic: %f' % kpss_test[0])
print('Critical Values @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])
# Out:
# KPSS Statistic: 4.091010
# Critical Values @ 0.05: 0.46
# p-value: 0.010000
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1874: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(warn_msg.format(direction="smaller"), InterpolationWarning)

# %% [markdown]
# Since, the p-value is less than 0.05, we can conclude that the data is non-stationary.

# %% [markdown]
# #### Box Cox transformation to make variance constant

# %%
from scipy.stats import boxcox
base_boxcox = pd.Series(boxcox(base['Close'], lmbda=0), index = base.index)

plt.figure(figsize=(12,4))
plt.plot(base_boxcox, label='After Box Cox tranformation')
plt.legend(loc='best')
plt.title('After Box Cox transform')
plt.show()

# %% [markdown]
# #### Differencing to remove trend

# %%
base_boxcox_diff = pd.Series(base_boxcox - base_boxcox.shift(), base.index)
plt.figure(figsize=(12,4))
plt.plot(base_boxcox_diff, label='After Box Cox tranformation and differencing')
plt.legend(loc='best')
plt.title('After Box Cox transform and differencing')
plt.show()

# %%
base_boxcox_diff.dropna(inplace=True)
base_boxcox_diff.head()
# Out:
# Date
# 2017-11-10   -0.069790
# 2017-11-11    0.050270
# 2017-11-12   -0.021758
# 2017-11-13    0.028204
# 2017-11-14    0.063948
# dtype: float64

# %% [markdown]
# #### Kwiatkowski-Phillips-Schmidt-Shin (KPSS) test for stationarity

# %%
kpss_test = kpss(base_boxcox_diff)

print('KPSS Statistic: %f' % kpss_test[0])
print('Critical Values @ 0.05: %.2f' % kpss_test[3]['5%'])
print('p-value: %f' % kpss_test[1])
# Out:
# KPSS Statistic: 0.149211
# Critical Values @ 0.05: 0.46
# p-value: 0.100000
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1876: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(warn_msg.format(direction="greater"), InterpolationWarning)

# %% [markdown]
# Since the p-value > 0.05, we can say the transformed series is stationary

# %% [markdown]
# #### ACF & PCF plots

# %%
from statsmodels.graphics.tsaplots import plot_acf
plt.figure(figsize=(12,4))
plot_acf(base_boxcox_diff, ax=plt.gca(), lags = 30)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plt.figure(figsize=(12,4))
plot_pacf(base_boxcox_diff, ax=plt.gca(), lags = 30)
plt.show()

# %%
train_data_boxcox = base_boxcox[:train_len]
test_data_boxcox = base_boxcox[train_len:]
train_data_boxcox_diff = base_boxcox_diff[:train_len-1]
test_data_boxcox_diff = base_boxcox_diff[train_len-1:]

# %%
train_data_boxcox_diff.shape
# Out:
# (1699,)

# %% [markdown]
# #### Base model - Auto regression moving average method (ARMA)

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(train_data_boxcox_diff, order=(1, 0, 1))
model_fit = model.fit()
print(model_fit.params)
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# const      0.000746
# ar.L1.y   -0.788095
# ma.L1.y    0.741785
# dtype: float64

# %%
# Reverse calculation to extract the original series
y_pred = base_boxcox_diff.copy()
y_pred['arma_forecast_boxcox_diff'] = model_fit.predict(base_boxcox_diff.index.min(), base_boxcox_diff.index.max())
y_pred['arma_forecast_boxcox'] = y_pred['arma_forecast_boxcox_diff'].cumsum()
y_pred['arma_forecast_boxcox'] = y_pred['arma_forecast_boxcox'].add(base_boxcox[0])
y_pred['arma_forecast'] = np.exp(y_pred['arma_forecast_boxcox'])

# %% [markdown]
# #### Plot train, test and forecast

# %%
plt.figure(figsize=(12,4))
plt.plot( base['Close'][:train_len], label='Train')
plt.plot(base['Close'][train_len:], label='Test')
plt.plot(y_pred['arma_forecast'][test.index.min():], label='ARMA forecast')
plt.legend(loc='best')
plt.title('ARMA Method')
plt.show()

# %% [markdown]
# #### Calculate RMSE and MAPE

# %%
test['Close'].shape
# Out:
# (86,)

# %%
test.head()
# Out:
#                   Close
# Date
# 2022-07-06  1186.973999
# 2022-07-07  1237.593384
# 2022-07-08  1222.506226
# 2022-07-09  1216.978271
# 2022-07-10  1168.401611

# %%
y_pred['arma_forecast'][train_len - 1:]
# Out:
# 2022-07-06    1141.590635
# 2022-07-07    1140.076554
# 2022-07-08    1142.792486
# 2022-07-09    1142.173571
# 2022-07-10    1144.186024
#                  ...
# 2022-09-25    1211.269311
# 2022-09-26    1212.172949
# 2022-09-27    1213.077261
# 2022-09-28    1213.982247
# 2022-09-29    1214.887909
# Freq: D, Length: 86, dtype: float64

# %%
y_pred['arma_forecast'].shape
# Out:
# (1785,)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_percentage_error

# %%
mse = mean_squared_error(test['Close'], y_pred['arma_forecast'][train_len -1 :]).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'], y_pred['arma_forecast'][train_len -1 :]).round(2)
mape = mean_absolute_percentage_error(test['Close'], y_pred['arma_forecast'][train_len -1 :]).round(4)*100
model_param = pd.DataFrame( columns = ['model', 'MSE','RMSE','R-Squared','MAPE'])

# %%
model_param.loc[0] = ['ARMA', mse, rmse, r2, mape]
model_param
# Out:
#   model       MSE    RMSE  R-Squared   MAPE
# 0  ARMA  177127.0  420.86      -2.93  22.48

# %%
a = y_pred['arma_forecast']

# %%
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-ARMA.xlsx')

# %%
b = pd.DataFrame(test['Close'])

# %%
b = pd.DataFrame(a)
b.columns = ['ARMA']
b['Close'] = test['Close']

# %% [markdown]
# #### Auto regressive integrated moving average (ARIMA)

# %%
model = ARIMA(train_data_boxcox, order=(1, 1, 1))
model_fit = model.fit()
print(model_fit.params)
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# const        0.000746
# ar.L1.D.y   -0.788095
# ma.L1.D.y    0.741785
# dtype: float64

# %%
# Reverse calculation to extract the original series
y_pred = base_boxcox_diff.copy()
y_pred['arma_forecast_boxcox_diff'] = model_fit.predict(base_boxcox_diff.index.min(), base_boxcox_diff.index.max())
y_pred['arma_forecast_boxcox'] = y_pred['arma_forecast_boxcox_diff'].cumsum()
y_pred['arma_forecast_boxcox'] = y_pred['arma_forecast_boxcox'].add(base_boxcox[0])
y_pred['arma_forecast'] = np.exp(y_pred['arma_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot( base['Close'][:train_len], label='Train')
plt.plot(base['Close'][train_len:], label='Test')
plt.plot(y_pred['arma_forecast'][test.index.min():], label='ARMA forecast')
plt.legend(loc='best')
plt.title('ARMA Method')
plt.show()

# %% [markdown]
# #### Calculate RMSE and MAPE

# %%
mse = mean_squared_error(test['Close'], y_pred['arma_forecast'][train_len -1 :]).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'], y_pred['arma_forecast'][train_len -1 :]).round(2)
mape = mean_absolute_percentage_error(test['Close'], y_pred['arma_forecast'][train_len -1 :]).round(4)*100

# %%
model_param.loc[1] = ['ARIMA', mse, rmse, r2, mape]
model_param
# Out:
#    model       MSE    RMSE  R-Squared   MAPE
# 0   ARMA  177127.0  420.86      -2.93  22.48
# 1  ARIMA  177127.0  420.86      -2.93  22.48

# %% [markdown]
# #### SARIMA Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(train_data_boxcox, order=(1, 1, 1), seasonal_order=(1, 1, 1, 52)) 
model_fit = model.fit()
print(model_fit.params)
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# ar.L1      -0.195331
# ma.L1       0.146944
# ar.S.L52    0.000078
# ma.S.L52   -0.962266
# sigma2      0.002756
# dtype: float64

# %%
# Reverse calculation to extract the original series
y_pred = base_boxcox_diff.copy()
y_pred['sarima_forecast_boxcox'] = model_fit.predict(base_boxcox_diff.index.min(), base_boxcox_diff.index.max())
y_pred['sarima_forecast'] = np.exp(y_pred['sarima_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot( base['Close'][:train_len], label='Train')
plt.plot(base['Close'][train_len:], label='Test')
plt.plot(y_pred['sarima_forecast'][test.index.min():], label='SARIMA forecast')
plt.legend(loc='best')
plt.title('SARIMA Method')
plt.show()

# %%
mse = mean_squared_error(test['Close'], y_pred['sarima_forecast'][test.index.min():]).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'], y_pred['sarima_forecast'][test.index.min():]).round(2)
mape = mean_absolute_percentage_error(test['Close'], y_pred['sarima_forecast'][test.index.min():]).round(4)*100

# %%
model_param.loc[2] = ['SARIMA', mse, rmse, r2, mape]
model_param
# Out:
#     model        MSE    RMSE  R-Squared   MAPE
# 0    ARMA  177127.00  420.86      -2.93  22.48
# 1   ARIMA  177127.00  420.86      -2.93  22.48
# 2  SARIMA  154234.99  392.73      -2.42  20.37

# %%
a = y_pred['sarima_forecast']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-SARIMA.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['SARIMA']
b = b.join(c)

# %% [markdown]
# #### SARIMAX with exogenous variable as Bitcoin data (Only base variables)

# %%
base.head()
# Out:
#                  Close
# Date
# 2017-11-09  320.884003
# 2017-11-10  299.252991
# 2017-11-11  314.681000
# 2017-11-12  307.907990
# 2017-11-13  316.716003

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1786 entries, 2017-11-09 to 2022-09-29
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1786 non-null   float64
# dtypes: float64(1)
# memory usage: 27.9 KB

# %%
btc_exo = btc[['Date', 'Close', 'Volume']]
btc_exo = btc_exo[btc_exo.Date >= '2017-11-09']
btc_exo = btc_exo.set_index('Date')
btc_exo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1786 entries, 2017-11-09 to 2022-09-29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1786 non-null   float64
#  1   Volume  1786 non-null   float64
# dtypes: float64(2)
# memory usage: 41.9 KB

# %%
btc_train = btc_exo[:train_len]
btc_test = btc_exo[train_len:]

# %%
model = SARIMAX(train_data_boxcox, order=(1, 1, 1), seasonal_order=(1, 1, 1, 52), exog=btc_train) 
SARIMAX_model_fit = model.fit()
print(SARIMAX_model_fit.params)
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Close       2.831444e-05
# Volume     -2.252627e-14
# ar.L1      -1.958800e-01
# ma.L1       1.731939e-01
# ar.S.L52   -1.704645e-01
# ma.S.L52   -5.317054e-01
# sigma2      3.445839e-03
# dtype: float64

# %%
# Reverse calculation to extract the original series
y_pred = base_boxcox_diff.copy()
y_pred['sarimax_forecast_boxcox'] = SARIMAX_model_fit.predict(base_boxcox_diff.index.min(), base_boxcox_diff.index.max(), exog=btc_test)
y_pred['sarimax_forecast'] = np.exp(y_pred['sarimax_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot( base['Close'][:train_len], label='Train')
plt.plot(base['Close'][train_len:], label='Test')
plt.plot(y_pred['sarimax_forecast'][test.index.min():], label='SARIMAX forecast')
plt.legend(loc='best')
plt.title('SARIMAX Method')
plt.show()

# %%
mse = mean_squared_error(test['Close'], y_pred['sarimax_forecast'][test.index.min():]).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'], y_pred['sarimax_forecast'][test.index.min():]).round(2)
mape = mean_absolute_percentage_error(test['Close'], y_pred['sarimax_forecast'][test.index.min():]).round(4)*100

# %%
model_param.loc[3] = ['SARIMAX - BTC Data', mse, rmse, r2, mape]
model_param
# Out:
#                 model        MSE    RMSE  R-Squared   MAPE
# 0                ARMA  177127.00  420.86      -2.93  22.48
# 1               ARIMA  177127.00  420.86      -2.93  22.48
# 2              SARIMA  154234.99  392.73      -2.42  20.37
# 3  SARIMAX - BTC Data  246822.36  496.81      -4.48  28.44

# %%
a = y_pred['sarimax_forecast']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-SARIMAX - BTC Data.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['SARIMAX - BTC Data']
b = b.join(c)

# %% [markdown]
# #### SARIMAX with exogenous variable as Bitcoin Feature Engineered variables

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1786 entries, 0 to 1785
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1786 non-null   datetime64[ns]
#  1   Close_btc          1786 non-null   float64
#  2   volume_fi          1786 non-null   float64
#  3   volume_nvi         1786 non-null   float64
#  4   volatility_ui      1786 non-null   float64
#  5   trend_macd_signal  1786 non-null   float64
#  6   trend_mass_index   1786 non-null   float64
#  7   trend_dpo          1786 non-null   float64
#  8   trend_kst_sig      1786 non-null   float64
#  9   trend_kst_diff     1786 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 153.5 KB

# %%
X = X.set_index('Date')
btc_train = X[:train_len]
btc_test = X[train_len:]

# %%
train_data_boxcox.head()
# Out:
# Date
# 2017-11-09    5.771080
# 2017-11-10    5.701289
# 2017-11-11    5.751559
# 2017-11-12    5.729801
# 2017-11-13    5.758005
# dtype: float64

# %%
btc_train.head()
# Out:
#               Close_btc     volume_fi   volume_nvi  volatility_ui  \
# Date
# 2017-11-09  7143.580078  0.000000e+00  1000.000000            0.0
# 2017-11-10  6618.140137 -2.736622e+12  1000.000000            0.0
# 2017-11-11  6357.600098 -2.528378e+12   960.632438            0.0
# 2017-11-12  5950.069824 -2.688665e+12   960.632438            0.0
# 2017-11-13  6559.490234 -1.759291e+12  1059.022715            0.0
#
#             trend_macd_signal  trend_mass_index     trend_dpo  trend_kst_sig  \
# Date
# 2017-11-09           0.000000          1.000000  13073.249208    -646.651808
# 2017-11-10          -8.383087          2.231297  13335.969178    -653.149364
# 2017-11-11         -25.718734          3.493030  13510.389182    -658.191038
# 2017-11-12         -54.200196          4.904593  13699.481752    -663.050182
# 2017-11-13         -78.328116          6.314975  13691.053212    -665.882286
#
#             trend_kst_diff
# Date
# 2017-11-09        0.000000
# 2017-11-10       -6.497556
# 2017-11-11      -10.083348
# 2017-11-12      -14.577430
# 2017-11-13      -11.328419

# %%
model = SARIMAX(train_data_boxcox, order=(1, 1, 1), seasonal_order=(1, 1, 1, 52), exog=btc_train) 
SARIMAX_model_fit = model.fit()
print(SARIMAX_model_fit.params)
# Out:
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# C:\Users\nikhi\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Close_btc            3.575543e-05
# volume_fi           -1.312489e-15
# volume_nvi           3.713090e-04
# volatility_ui       -7.775814e-03
# trend_macd_signal   -1.072406e-04
# trend_mass_index    -4.165744e-03
# trend_dpo           -3.913702e-07
# trend_kst_sig        2.496595e-04
# trend_kst_diff       6.801651e-04
# ar.L1               -1.538024e-01
# ma.L1                1.425654e-01
# ar.S.L52            -1.478749e-01
# ma.S.L52            -5.523526e-01
# sigma2               3.174246e-03
# dtype: float64

# %%
# Reverse calculation to extract the original series
y_pred = base_boxcox_diff.copy()
y_pred['sarimax_forecast_boxcox'] = SARIMAX_model_fit.predict(base_boxcox_diff.index.min(), base_boxcox_diff.index.max(), exog=btc_test)
y_pred['sarimax_forecast'] = np.exp(y_pred['sarimax_forecast_boxcox'])

# %%
plt.figure(figsize=(12,4))
plt.plot( base['Close'][:train_len], label='Train')
plt.plot(base['Close'][train_len:], label='Test')
plt.plot(y_pred['sarimax_forecast'][test.index.min():], label='SARIMAX forecast')
plt.legend(loc='best')
plt.title('SARIMAX Method')
plt.show()

# %%
mse = mean_squared_error(test['Close'], y_pred['sarimax_forecast'][test.index.min():]).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'], y_pred['sarimax_forecast'][test.index.min():]).round(2)
mape = mean_absolute_percentage_error(test['Close'], y_pred['sarimax_forecast'][test.index.min():]).round(4)*100

# %%
model_param.loc[4] = ['SARIMAX - BTC data along with FE variables', mse, rmse, r2, mape]
model_param
# Out:
#                                         model        MSE    RMSE  R-Squared  \
# 0                                        ARMA  177127.00  420.86      -2.93
# 1                                       ARIMA  177127.00  420.86      -2.93
# 2                                      SARIMA  154234.99  392.73      -2.42
# 3                          SARIMAX - BTC Data  246822.36  496.81      -4.48
# 4  SARIMAX - BTC data along with FE variables  309598.02  556.42      -5.87
#
#     MAPE
# 0  22.48
# 1  22.48
# 2  20.37
# 3  28.44
# 4  31.86

# %%
a = y_pred['sarimax_forecast']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-SARIMAX - BTC data along with FE variables.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['SARIMAX - BTC FE Data']
b = b.join(c)

# %% [markdown]
# #### Random Forest
# - No external data. Only lag of one day.

# %%
eth_rf = base.copy()
eth_rf['Close_lag_1'] = eth_rf['Close'].shift(1)
eth_rf.dropna(inplace=True)
eth_rf.head()
# Out:
#                  Close  Close_lag_1
# Date
# 2017-11-10  299.252991   320.884003
# 2017-11-11  314.681000   299.252991
# 2017-11-12  307.907990   314.681000
# 2017-11-13  316.716003   307.907990
# 2017-11-14  337.631012   316.716003

# %%
rf_crypto = eth_rf
rf_crypto.head()
# Out:
#                  Close  Close_lag_1
# Date
# 2017-11-10  299.252991   320.884003
# 2017-11-11  314.681000   299.252991
# 2017-11-12  307.907990   314.681000
# 2017-11-13  316.716003   307.907990
# 2017-11-14  337.631012   316.716003

# %%
y_rf = rf_crypto['Close']
X_rf = rf_crypto.drop('Close', axis=1)

# %%
X_rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1785 entries, 2017-11-10 to 2022-09-29
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Close_lag_1  1785 non-null   float64
# dtypes: float64(1)
# memory usage: 27.9 KB

# %%
X_rf_train = X_rf[:train_len]
X_rf_test = X_rf[train_len:]
y_rf_train = y_rf[:train_len]
y_rf_test = y_rf[train_len:]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(n_estimators=20, max_depth=10, bootstrap=True, oob_score=True, n_jobs=-1)
rf_model.fit(X_rf_train, y_rf_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20, n_jobs=-1, oob_score=True)

# %%
y_rf_pred = rf_model.predict(X_rf_test)

# %%
y_rf_test.index
# Out:
# DatetimeIndex(['2022-07-07', '2022-07-08', '2022-07-09', '2022-07-10',
#                '2022-07-11', '2022-07-12', '2022-07-13', '2022-07-14',
#                '2022-07-15', '2022-07-16', '2022-07-17', '2022-07-18',
#                '2022-07-19', '2022-07-20', '2022-07-21', '2022-07-22',
#                '2022-07-23', '2022-07-24', '2022-07-25', '2022-07-26',
#                '2022-07-27', '2022-07-28', '2022-07-29', '2022-07-30',
#                '2022-07-31', '2022-08-01', '2022-08-02', '2022-08-03',
#                '2022-08-04', '2022-08-05', '2022-08-06', '2022-08-07',
#                '2022-08-08', '2022-08-09', '2022-08-10', '2022-08-11',
#                '2022-08-12', '2022-08-13', '2022-08-14', '2022-08-15',
#                '2022-08-16', '2022-08-17', '2022-08-18', '2022-08-19',
#                '2022-08-20', '2022-08-21', '2022-08-22', '2022-08-23',
#                '2022-08-24', '2022-08-25', '2022-08-26', '2022-08-27',
#                '2022-08-28', '2022-08-29', '2022-08-30', '2022-08-31',
#                '2022-09-01', '2022-09-02', '2022-09-03', '2022-09-04',
#                '2022-09-05', '2022-09-06', '2022-09-07', '2022-09-08',
#                '2022-09-09', '2022-09-10', '2022-09-11', '2022-09-12',
#                '2022-09-13', '2022-09-14', '2022-09-15', '2022-09-16',
#                '2022-09-17', '2022-09-18', '2022-09-19', '2022-09-20',
#                '2022-09-21', '2022-09-22', '2022-09-23', '2022-09-24',
#                '2022-09-25', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
y_rf_pred_df = pd.DataFrame(y_rf_pred)
y_rf_pred_df['Date'] = y_rf_test.index
y_rf_pred_df = y_rf_pred_df.set_index('Date')
y_rf_pred_s = y_rf_pred_df.squeeze()

# %%
plt.figure(figsize=(12,4))
plt.plot( y_rf_train, label='Train')
plt.plot(y_rf_test, label='Test')
plt.plot(y_rf_pred_s, label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_rf_test, y_rf_pred_s).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_rf_test, y_rf_pred_s).round(2)
mape = np.round(np.mean(np.abs(y_rf_test - y_rf_pred_s)/y_rf_test)*100,2)

# %%
model_param.loc[5] = ['Random Forest - 1 lag, No Ext Var', mse, rmse, r2, mape]
model_param
# Out:
#                                         model        MSE    RMSE  R-Squared  \
# 0                                        ARMA  177127.00  420.86      -2.93
# 1                                       ARIMA  177127.00  420.86      -2.93
# 2                                      SARIMA  154234.99  392.73      -2.42
# 3                          SARIMAX - BTC Data  246822.36  496.81      -4.48
# 4  SARIMAX - BTC data along with FE variables  309598.02  556.42      -5.87
# 5           Random Forest - 1 lag, No Ext Var   11003.63  104.90       0.75
#
#     MAPE
# 0  22.48
# 1  22.48
# 2  20.37
# 3  28.44
# 4  31.86
# 5   5.32

# %%
a = y_rf_pred_s
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth- Random Forest - 1 lag, No Ext Var.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['Random Forest - 1 lag, No Ext Var']
b = b.join(c)

# %% [markdown]
# #### Random Forest
# - Daily lag till 7 days and Feature Engineered data of Bitcoin.

# %%
eth_rf = base.copy()
eth_rf['Close_lag_1'] = eth_rf['Close'].shift(1)
eth_rf['Close_lag_2'] = eth_rf['Close'].shift(2)
eth_rf['Close_lag_3'] = eth_rf['Close'].shift(3)
eth_rf['Close_lag_4'] = eth_rf['Close'].shift(4)
eth_rf['Close_lag_5'] = eth_rf['Close'].shift(5)
eth_rf['Close_lag_6'] = eth_rf['Close'].shift(6)
eth_rf['Close_lag_7'] = eth_rf['Close'].shift(7)
eth_rf.dropna(inplace=True)
eth_rf.head()
# Out:
#                  Close  Close_lag_1  Close_lag_2  Close_lag_3  Close_lag_4  \
# Date
# 2017-11-16  330.924011   333.356995   337.631012   316.716003   307.907990
# 2017-11-17  332.394012   330.924011   333.356995   337.631012   316.716003
# 2017-11-18  347.612000   332.394012   330.924011   333.356995   337.631012
# 2017-11-19  354.385986   347.612000   332.394012   330.924011   333.356995
# 2017-11-20  366.730011   354.385986   347.612000   332.394012   330.924011
#
#             Close_lag_5  Close_lag_6  Close_lag_7
# Date
# 2017-11-16   314.681000   299.252991   320.884003
# 2017-11-17   307.907990   314.681000   299.252991
# 2017-11-18   316.716003   307.907990   314.681000
# 2017-11-19   337.631012   316.716003   307.907990
# 2017-11-20   333.356995   337.631012   316.716003

# %%
# Bitcoin feature engineered data
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1786 entries, 2017-11-09 to 2022-09-29
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Close_btc          1786 non-null   float64
#  1   volume_fi          1786 non-null   float64
#  2   volume_nvi         1786 non-null   float64
#  3   volatility_ui      1786 non-null   float64
#  4   trend_macd_signal  1786 non-null   float64
#  5   trend_mass_index   1786 non-null   float64
#  6   trend_dpo          1786 non-null   float64
#  7   trend_kst_sig      1786 non-null   float64
#  8   trend_kst_diff     1786 non-null   float64
# dtypes: float64(9)
# memory usage: 139.5 KB

# %%
rf_crypto = X.merge(eth_rf, on='Date')

# %%
y_rf = rf_crypto['Close']
X_rf = rf_crypto.drop('Close', axis=1)

X_rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1779 entries, 2017-11-16 to 2022-09-29
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Close_btc          1779 non-null   float64
#  1   volume_fi          1779 non-null   float64
#  2   volume_nvi         1779 non-null   float64
#  3   volatility_ui      1779 non-null   float64
#  4   trend_macd_signal  1779 non-null   float64
#  5   trend_mass_index   1779 non-null   float64
#  6   trend_dpo          1779 non-null   float64
#  7   trend_kst_sig      1779 non-null   float64
#  8   trend_kst_diff     1779 non-null   float64
#  9   Close_lag_1        1779 non-null   float64
#  10  Close_lag_2        1779 non-null   float64
#  11  Close_lag_3        1779 non-null   float64
#  12  Close_lag_4        1779 non-null   float64
#  13  Close_lag_5        1779 non-null   float64
#  14  Close_lag_6        1779 non-null   float64
#  15  Close_lag_7        1779 non-null   float64
# dtypes: float64(16)
# memory usage: 236.3 KB

# %%
X_rf_train = X_rf[:train_len]
X_rf_test = X_rf[train_len:]
y_rf_train = y_rf[:train_len]
y_rf_test = y_rf[train_len:]

# %%
rf_model = RandomForestRegressor(n_estimators=20, max_depth=10, bootstrap=True, oob_score=True, n_jobs=-1)
rf_model.fit(X_rf_train, y_rf_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20, n_jobs=-1, oob_score=True)

# %%
y_rf_pred = rf_model.predict(X_rf_test)

# %%
y_rf_test.index
# Out:
# DatetimeIndex(['2022-07-13', '2022-07-14', '2022-07-15', '2022-07-16',
#                '2022-07-17', '2022-07-18', '2022-07-19', '2022-07-20',
#                '2022-07-21', '2022-07-22', '2022-07-23', '2022-07-24',
#                '2022-07-25', '2022-07-26', '2022-07-27', '2022-07-28',
#                '2022-07-29', '2022-07-30', '2022-07-31', '2022-08-01',
#                '2022-08-02', '2022-08-03', '2022-08-04', '2022-08-05',
#                '2022-08-06', '2022-08-07', '2022-08-08', '2022-08-09',
#                '2022-08-10', '2022-08-11', '2022-08-12', '2022-08-13',
#                '2022-08-14', '2022-08-15', '2022-08-16', '2022-08-17',
#                '2022-08-18', '2022-08-19', '2022-08-20', '2022-08-21',
#                '2022-08-22', '2022-08-23', '2022-08-24', '2022-08-25',
#                '2022-08-26', '2022-08-27', '2022-08-28', '2022-08-29',
#                '2022-08-30', '2022-08-31', '2022-09-01', '2022-09-02',
#                '2022-09-03', '2022-09-04', '2022-09-05', '2022-09-06',
#                '2022-09-07', '2022-09-08', '2022-09-09', '2022-09-10',
#                '2022-09-11', '2022-09-12', '2022-09-13', '2022-09-14',
#                '2022-09-15', '2022-09-16', '2022-09-17', '2022-09-18',
#                '2022-09-19', '2022-09-20', '2022-09-21', '2022-09-22',
#                '2022-09-23', '2022-09-24', '2022-09-25', '2022-09-26',
#                '2022-09-27', '2022-09-28', '2022-09-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
y_rf_pred_df = pd.DataFrame(y_rf_pred)
y_rf_pred_df['Date'] = y_rf_test.index
y_rf_pred_df = y_rf_pred_df.set_index('Date')
y_rf_pred_s = y_rf_pred_df.squeeze()

# %%
plt.figure(figsize=(12,4))
plt.plot( y_rf_train, label='Train')
plt.plot(y_rf_test, label='Test')
plt.plot(y_rf_pred_s, label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_rf_test, y_rf_pred_s).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_rf_test, y_rf_pred_s).round(2)
mape = np.round(np.mean(np.abs(y_rf_test - y_rf_pred_s)/y_rf_test)*100,2)

# %%
model_param.loc[6] = ['Random Forest - 7 lags with BTC FE Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                           model        MSE    RMSE  R-Squared  \
# 0                                          ARMA  177127.00  420.86      -2.93
# 1                                         ARIMA  177127.00  420.86      -2.93
# 2                                        SARIMA  154234.99  392.73      -2.42
# 3                            SARIMAX - BTC Data  246822.36  496.81      -4.48
# 4    SARIMAX - BTC data along with FE variables  309598.02  556.42      -5.87
# 5             Random Forest - 1 lag, No Ext Var   11003.63  104.90       0.75
# 6  Random Forest - 7 lags with BTC FE Variables   10385.19  101.91       0.70
#
#     MAPE
# 0  22.48
# 1  22.48
# 2  20.37
# 3  28.44
# 4  31.86
# 5   5.32
# 6   5.28

# %%
a = y_rf_pred_s
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth- Random Forest - 7 lags with BTC FE Variables.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['Random Forest - 7 lags with BTC FE Variables']
b = b.join(c)

# %% [markdown]
# #### Random Forest
# - No lag data. Only Feature Engineered Bitcoin variables.

# %%
eth_rf = base.copy()
eth_rf.head()
# Out:
#                  Close
# Date
# 2017-11-09  320.884003
# 2017-11-10  299.252991
# 2017-11-11  314.681000
# 2017-11-12  307.907990
# 2017-11-13  316.716003

# %%
# Bitcoin feature engineered data
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1786 entries, 2017-11-09 to 2022-09-29
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Close_btc          1786 non-null   float64
#  1   volume_fi          1786 non-null   float64
#  2   volume_nvi         1786 non-null   float64
#  3   volatility_ui      1786 non-null   float64
#  4   trend_macd_signal  1786 non-null   float64
#  5   trend_mass_index   1786 non-null   float64
#  6   trend_dpo          1786 non-null   float64
#  7   trend_kst_sig      1786 non-null   float64
#  8   trend_kst_diff     1786 non-null   float64
# dtypes: float64(9)
# memory usage: 139.5 KB

# %%
rf_crypto = X.merge(eth_rf, on='Date')

# %%
y_rf = rf_crypto['Close']
X_rf = rf_crypto.drop('Close', axis=1)

X_rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1786 entries, 2017-11-09 to 2022-09-29
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Close_btc          1786 non-null   float64
#  1   volume_fi          1786 non-null   float64
#  2   volume_nvi         1786 non-null   float64
#  3   volatility_ui      1786 non-null   float64
#  4   trend_macd_signal  1786 non-null   float64
#  5   trend_mass_index   1786 non-null   float64
#  6   trend_dpo          1786 non-null   float64
#  7   trend_kst_sig      1786 non-null   float64
#  8   trend_kst_diff     1786 non-null   float64
# dtypes: float64(9)
# memory usage: 139.5 KB

# %%
X_rf_train = X_rf[:train_len]
X_rf_test = X_rf[train_len:]
y_rf_train = y_rf[:train_len]
y_rf_test = y_rf[train_len:]

# %%
rf_model = RandomForestRegressor(n_estimators=20, max_depth=10, bootstrap=True, oob_score=True, n_jobs=-1)
rf_model.fit(X_rf_train, y_rf_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20, n_jobs=-1, oob_score=True)

# %%
y_rf_pred = rf_model.predict(X_rf_test)

# %%
y_rf_test.index
# Out:
# DatetimeIndex(['2022-07-06', '2022-07-07', '2022-07-08', '2022-07-09',
#                '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13',
#                '2022-07-14', '2022-07-15', '2022-07-16', '2022-07-17',
#                '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#                '2022-07-22', '2022-07-23', '2022-07-24', '2022-07-25',
#                '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-29',
#                '2022-07-30', '2022-07-31', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-05', '2022-08-06',
#                '2022-08-07', '2022-08-08', '2022-08-09', '2022-08-10',
#                '2022-08-11', '2022-08-12', '2022-08-13', '2022-08-14',
#                '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18',
#                '2022-08-19', '2022-08-20', '2022-08-21', '2022-08-22',
#                '2022-08-23', '2022-08-24', '2022-08-25', '2022-08-26',
#                '2022-08-27', '2022-08-28', '2022-08-29', '2022-08-30',
#                '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-03',
#                '2022-09-04', '2022-09-05', '2022-09-06', '2022-09-07',
#                '2022-09-08', '2022-09-09', '2022-09-10', '2022-09-11',
#                '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15',
#                '2022-09-16', '2022-09-17', '2022-09-18', '2022-09-19',
#                '2022-09-20', '2022-09-21', '2022-09-22', '2022-09-23',
#                '2022-09-24', '2022-09-25', '2022-09-26', '2022-09-27',
#                '2022-09-28', '2022-09-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
y_rf_pred_df = pd.DataFrame(y_rf_pred)
y_rf_pred_df['Date'] = y_rf_test.index
y_rf_pred_df = y_rf_pred_df.set_index('Date')
y_rf_pred_s = y_rf_pred_df.squeeze()

# %%
plt.figure(figsize=(12,4))
plt.plot( y_rf_train, label='Train')
plt.plot(y_rf_test, label='Test')
plt.plot(y_rf_pred_s, label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
print(y_rf_test.shape)
print(y_rf_pred_s.shape)
# Out:
# (86,)
# (86,)

# %%
mse = mean_squared_error(y_rf_test, y_rf_pred_s).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'], y_rf_pred_s).round(2)
mape = np.round(np.mean(np.abs(y_rf_test - y_rf_pred_s)/y_rf_test)*100,2)

# %%
model_param.loc[7] = ['Random Forest - No lags with BTC FE Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                            model        MSE    RMSE  \
# 0                                           ARMA  177127.00  420.86
# 1                                          ARIMA  177127.00  420.86
# 2                                         SARIMA  154234.99  392.73
# 3                             SARIMAX - BTC Data  246822.36  496.81
# 4     SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5              Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6   Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7  Random Forest - No lags with BTC FE Variables  326800.32  571.66
#
#    R-Squared   MAPE
# 0      -2.93  22.48
# 1      -2.93  22.48
# 2      -2.42  20.37
# 3      -4.48  28.44
# 4      -5.87  31.86
# 5       0.75   5.32
# 6       0.70   5.28
# 7      -6.25  29.61

# %%
a = y_rf_pred_s
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth- Random Forest - No lags with BTC FE Variables.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['Random Forest - No lags with BTC FE Variables']
b = b.join(c)

# %% [markdown]
# #### Random Forest with Scaling

# %%
rf_crypto.head()
# Out:
#               Close_btc     volume_fi   volume_nvi  volatility_ui  \
# Date
# 2017-11-09  7143.580078  0.000000e+00  1000.000000            0.0
# 2017-11-10  6618.140137 -2.736622e+12  1000.000000            0.0
# 2017-11-11  6357.600098 -2.528378e+12   960.632438            0.0
# 2017-11-12  5950.069824 -2.688665e+12   960.632438            0.0
# 2017-11-13  6559.490234 -1.759291e+12  1059.022715            0.0
#
#             trend_macd_signal  trend_mass_index     trend_dpo  trend_kst_sig  \
# Date
# 2017-11-09           0.000000          1.000000  13073.249208    -646.651808
# 2017-11-10          -8.383087          2.231297  13335.969178    -653.149364
# 2017-11-11         -25.718734          3.493030  13510.389182    -658.191038
# 2017-11-12         -54.200196          4.904593  13699.481752    -663.050182
# 2017-11-13         -78.328116          6.314975  13691.053212    -665.882286
#
#             trend_kst_diff       Close
# Date
# 2017-11-09        0.000000  320.884003
# 2017-11-10       -6.497556  299.252991
# 2017-11-11      -10.083348  314.681000
# 2017-11-12      -14.577430  307.907990
# 2017-11-13      -11.328419  316.716003

# %%
train = rf_crypto[0:train_len]
test = rf_crypto[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 10)
# test :  (86, 10)

# %%
train.describe()
# Out:
#           Close_btc     volume_fi   volume_nvi  volatility_ui  \
# count   1700.000000  1.700000e+03  1700.000000    1700.000000
# mean   20158.732018 -5.497542e+11   368.536666       8.786382
# std    17658.394042  1.795095e+13   250.565008       6.746662
# min     3236.761719 -1.743559e+14   126.539314       0.000000
# 25%     7416.697021 -1.549142e+12   199.358990       3.695153
# 50%    10232.671875  7.813286e+08   287.408403       6.767541
# 75%    35720.534182  1.834706e+12   451.693239      12.192157
# max    67566.828130  1.324492e+14  1471.342938      34.592181
#
#        trend_macd_signal  trend_mass_index     trend_dpo  trend_kst_sig  \
# count        1700.000000       1700.000000   1700.000000    1700.000000
# mean           71.496160         24.813869     74.552684      25.079154
# std          1209.980689          2.399198   1742.947962     193.620350
# min         -4438.999056          1.000000  -5941.385154    -668.081207
# 25%          -328.768909         23.554791   -443.481561     -82.961552
# 50%           -21.736146         24.750949    -19.135009      -0.583739
# 75%           399.458945         25.831136    352.993408     141.546623
# max          4517.102703         30.161784  13699.481752     845.656151
#
#        trend_kst_diff        Close
# count     1700.000000  1700.000000
# mean         0.963486  1099.730724
# std         59.494663  1243.238165
# min       -286.656521    84.308296
# 25%        -32.667633   201.970074
# 50%         -1.046092   428.491867
# 75%         29.332642  1861.479462
# max        300.209413  4812.087402

# %%
# Check distribution of few variables
plt.figure(figsize=[15,8])

plt.subplot(5,2,1)
plt.title('Distribution of Close_btc', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.Close_btc)

plt.subplot(5,2,2)
plt.title('Distribution of volume_fi', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.volume_fi)

plt.subplot(5,2,3)
plt.title('Distribution of volume_nvi', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.volume_nvi)

plt.subplot(5,2,4)
plt.title('Distribution of volatility_ui', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.volatility_ui)

plt.subplot(5,2,5)
plt.title('Distribution of trend_macd_signal', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.trend_macd_signal)

plt.subplot(5,2,6)
plt.title('Distribution of trend_mass_index', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.trend_mass_index)

plt.subplot(5,2,7)
plt.title('Distribution of trend_dpo', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.trend_dpo)

plt.subplot(5,2,8)
plt.title('Distribution of trend_kst_sig', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.trend_kst_sig)

plt.subplot(5,2,9)
plt.title('Distribution of trend_kst_diff', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.trend_kst_diff)

plt.subplot(5,2,10)
plt.title('Distribution of Close', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(train.Close)

plt.tight_layout(pad=2.0)
plt.show()

# %%
# Lets try various scalers available in Scikit library. At optimum time, will finalize one.
# Based on various test results, QuantileTransformer with Gaussian distribution seems best suited.
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import RobustScaler
#scaler = MinMaxScaler()
#scaler = StandardScaler()
#scaler = PowerTransformer()
scaler = QuantileTransformer(output_distribution='normal')
#scaler = RobustScaler()

# %%
# Identify the variables to be scaled
vars_to_scale = ['Close_btc',
                'volume_fi',
                'volume_nvi',
                'volatility_ui',
                'trend_macd_signal',
                'trend_mass_index',
                'trend_dpo',
                'trend_kst_sig',
                'trend_kst_diff',
                'Close']

# %%
X_train_sc = train.copy()
X_test_sc = test.copy()

# %%
X_train_sc[vars_to_scale] = scaler.fit_transform(train[vars_to_scale])
X_test_sc[vars_to_scale] = scaler.transform(test[vars_to_scale])

# %%
X_train_sc.describe()
# Out:
#          Close_btc    volume_fi    volume_nvi  volatility_ui  \
# count  1700.000000  1700.000000  1.700000e+03    1700.000000
# mean     -0.000064    -0.000025  9.945859e-05      -0.017303
# std       1.011808     1.011301  1.011494e+00       1.077993
# min      -5.199338    -5.199338 -5.199338e+00      -5.199338
# 25%      -0.674498    -0.674382 -6.767490e-01      -0.675086
# 50%       0.000799     0.000227  6.960578e-17       0.000094
# 75%       0.674475     0.674740  6.742801e-01       0.676154
# max       5.199338     5.199338  5.199338e+00       5.199338
#
#        trend_macd_signal  trend_mass_index    trend_dpo  trend_kst_sig  \
# count        1700.000000       1700.000000  1700.000000    1700.000000
# mean            0.000081         -0.000028     0.000095      -0.000013
# std             1.012457          1.011441     1.012060       1.011755
# min            -5.199338         -5.199338    -5.199338      -5.199338
# 25%            -0.673960         -0.674250    -0.674735      -0.674160
# 50%            -0.000407          0.000073     0.000065       0.000171
# 75%             0.674551          0.674237     0.673896       0.675225
# max             5.199338          5.199338     5.199338       5.199338
#
#        trend_kst_diff        Close
# count     1700.000000  1700.000000
# mean         0.000086    -0.000266
# std          1.011927     1.012252
# min         -5.199338    -5.199338
# 25%         -0.674747    -0.675552
# 50%         -0.000565     0.000573
# 75%          0.674279     0.674422
# max          5.199338     5.199338

# %%
# Check distribution of few variables
plt.figure(figsize=[15,8])

plt.subplot(5,2,1)
plt.title('Distribution of Close_btc', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.Close_btc)

plt.subplot(5,2,2)
plt.title('Distribution of volume_fi', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.volume_fi)

plt.subplot(5,2,3)
plt.title('Distribution of volume_nvi', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.volume_nvi)

plt.subplot(5,2,4)
plt.title('Distribution of volatility_ui', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.volatility_ui)

plt.subplot(5,2,5)
plt.title('Distribution of trend_macd_signal', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.trend_macd_signal)

plt.subplot(5,2,6)
plt.title('Distribution of trend_mass_index', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.trend_mass_index)

plt.subplot(5,2,7)
plt.title('Distribution of trend_dpo', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.trend_dpo)

plt.subplot(5,2,8)
plt.title('Distribution of trend_kst_sig', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.trend_kst_sig)

plt.subplot(5,2,9)
plt.title('Distribution of trend_kst_diff', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.trend_kst_diff)

plt.subplot(5,2,10)
plt.title('Distribution of Close', fontsize= 10, color = 'Red', fontweight = 100)
plt.hist(X_train_sc.Close)

plt.tight_layout(pad=2.0)
plt.show()

# %%
y_train_sc = X_train_sc['Close']
X_train_sc = X_train_sc.drop(['Close'], axis=1)
y_test_sc = X_test_sc['Close']
X_test_sc = X_test_sc.drop(['Close'], axis=1)

# %%
print(y_train_sc.shape)
print(X_train_sc.shape)
print(y_test_sc.shape)
print(X_test_sc.shape)
# Out:
# (1700,)
# (1700, 9)
# (86,)
# (86, 9)

# %%
rf_model = RandomForestRegressor(n_estimators=20, max_depth=10, bootstrap=True, oob_score=True, n_jobs=-1)
rf_model.fit(X_train_sc, y_train_sc)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20, n_jobs=-1, oob_score=True)

# %%
y_pred_sc = rf_model.predict(X_test_sc)
y_pred_sc.shape
# Out:
# (86,)

# %%
y_test_sc.index
# Out:
# DatetimeIndex(['2022-07-06', '2022-07-07', '2022-07-08', '2022-07-09',
#                '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13',
#                '2022-07-14', '2022-07-15', '2022-07-16', '2022-07-17',
#                '2022-07-18', '2022-07-19', '2022-07-20', '2022-07-21',
#                '2022-07-22', '2022-07-23', '2022-07-24', '2022-07-25',
#                '2022-07-26', '2022-07-27', '2022-07-28', '2022-07-29',
#                '2022-07-30', '2022-07-31', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-05', '2022-08-06',
#                '2022-08-07', '2022-08-08', '2022-08-09', '2022-08-10',
#                '2022-08-11', '2022-08-12', '2022-08-13', '2022-08-14',
#                '2022-08-15', '2022-08-16', '2022-08-17', '2022-08-18',
#                '2022-08-19', '2022-08-20', '2022-08-21', '2022-08-22',
#                '2022-08-23', '2022-08-24', '2022-08-25', '2022-08-26',
#                '2022-08-27', '2022-08-28', '2022-08-29', '2022-08-30',
#                '2022-08-31', '2022-09-01', '2022-09-02', '2022-09-03',
#                '2022-09-04', '2022-09-05', '2022-09-06', '2022-09-07',
#                '2022-09-08', '2022-09-09', '2022-09-10', '2022-09-11',
#                '2022-09-12', '2022-09-13', '2022-09-14', '2022-09-15',
#                '2022-09-16', '2022-09-17', '2022-09-18', '2022-09-19',
#                '2022-09-20', '2022-09-21', '2022-09-22', '2022-09-23',
#                '2022-09-24', '2022-09-25', '2022-09-26', '2022-09-27',
#                '2022-09-28', '2022-09-29'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
y_pred_sc_df = pd.DataFrame(y_pred_sc)
y_pred_sc_df['Date'] = y_test_sc.index
y_pred_sc_df = y_pred_sc_df.set_index('Date')
X_test_inv_sc = X_test_sc.copy()
X_test_inv_sc['Close_pred'] = y_pred_sc_df[0]
X_test_inv_sc.head()
#y_pred_sc_s = y_pred_sc_df.squeeze()
# Out:
#             Close_btc  volume_fi  volume_nvi  volatility_ui  \
# Date
# 2022-07-06   0.450827  -0.501821    0.420416       0.844249
# 2022-07-07   0.464272   0.867622    0.420416       0.509029
# 2022-07-08   0.464573   0.878692    0.420416       0.270147
# 2022-07-09   0.464126   0.770837    0.415124       0.059652
# 2022-07-10   0.456694  -0.532829    0.332869       0.041802
#
#             trend_macd_signal  trend_mass_index  trend_dpo  trend_kst_sig  \
# Date
# 2022-07-06          -1.578360         -0.315776   1.215878      -1.585544
# 2022-07-07          -1.529852         -0.332979   0.959139      -1.548167
# 2022-07-08          -1.469914         -0.558831   0.517133      -1.507311
# 2022-07-09          -1.420336         -0.805257  -0.439909      -1.430381
# 2022-07-10          -1.370003         -1.172498  -0.680463      -1.370373
#
#             trend_kst_diff  Close_pred
# Date
# 2022-07-06        0.853392    0.484512
# 2022-07-07        0.987340    0.462795
# 2022-07-08        1.089160    0.464195
# 2022-07-09        1.120023    0.465009
# 2022-07-10        1.115342    0.498374

# %%
X_test_inv = scaler.inverse_transform(X_test_inv_sc)
#X_test_inv_sc = pd.DataFrame(X_test_inv_sc)
X_test_inv_df = pd.DataFrame(X_test_inv, columns = ['Close_btc',
                                                    'volume_fi',
                                                    'volume_nvi',
                                                    'volatility_ui',
                                                    'trend_macd_signal',
                                                    'trend_mass_index',
                                                    'trend_dpo',
                                                    'trend_kst_sig',
                                                    'trend_kst_diff',
                                                    'Close'])
X_test_inv_df['Date'] = y_test_sc.index
X_test_inv_df = X_test_inv_df.set_index('Date')
X_test_inv_df.head()
# Out:
#               Close_btc     volume_fi  volume_nvi  volatility_ui  \
# Date
# 2022-07-06  20548.24609 -7.682419e+11  405.205200      13.395579
# 2022-07-07  21637.58789  3.358840e+12  405.205200      11.199343
# 2022-07-08  21731.11719  3.545733e+12  405.205200       8.960501
# 2022-07-09  21592.20703  2.450992e+12  402.615038       7.261155
# 2022-07-10  20860.44922 -8.981863e+11  388.970453       7.107910
#
#             trend_macd_signal  trend_mass_index    trend_dpo  trend_kst_sig  \
# Date
# 2022-07-06       -1940.857091         24.146317  1208.842284    -252.612251
# 2022-07-07       -1822.303435         24.127691   675.494041    -242.882655
# 2022-07-08       -1688.177663         23.736990   248.003910    -231.916455
# 2022-07-09       -1549.691217         23.341943  -258.786617    -219.731825
# 2022-07-10       -1423.873982         22.983717  -448.443553    -206.913860
#
#             trend_kst_diff        Close
# Date
# 2022-07-06       40.134706  1162.363068
# 2022-07-07       48.813111  1117.243978
# 2022-07-08       54.835205  1122.165385
# 2022-07-09       57.299756  1123.676881
# 2022-07-10       56.801347  1222.157968

# %%
plt.figure(figsize=(12,4))
plt.plot( y_rf_train, label='Train')
plt.plot(y_rf_test, label='Test')
plt.plot(X_test_inv_df['Close'], label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
y_rf_test.shape
# Out:
# (86,)

# %%
X_test_inv_df['Close'].shape
# Out:
# (86,)

# %%
mse = mean_squared_error(y_rf_test, X_test_inv_df['Close']).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_rf_test, X_test_inv_df['Close']).round(2)
mape = np.round(np.mean(np.abs(y_rf_test - X_test_inv_df['Close'])/y_rf_test)*100,2)

# %%
model_param.loc[8] = ['Random Forest - No lags with BTC SC FE Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                               model        MSE    RMSE  \
# 0                                              ARMA  177127.00  420.86
# 1                                             ARIMA  177127.00  420.86
# 2                                            SARIMA  154234.99  392.73
# 3                                SARIMAX - BTC Data  246822.36  496.81
# 4        SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                 Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6      Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7     Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8  Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
#
#    R-Squared   MAPE
# 0      -2.93  22.48
# 1      -2.93  22.48
# 2      -2.42  20.37
# 3      -4.48  28.44
# 4      -5.87  31.86
# 5       0.75   5.32
# 6       0.70   5.28
# 7      -6.25  29.61
# 8      -8.29  34.85

# %%
a = X_test_inv_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-Random Forest - No lags with BTC SC FE Variables.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['Random Forest - No lags with BTC SC FE Variables']
b = b.join(c)

# %% [markdown]
# #### Random Forest
# - No lag, ETH base data

# %%
eth_rf = eth.copy()
eth_rf = eth_rf.set_index('Date')
eth_rf.head()
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003   893249984
# 2017-11-10  320.670990  324.717987  294.541992  299.252991   885985984
# 2017-11-11  298.585999  319.453003  298.191986  314.681000   842300992
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  1613479936
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  1041889984

# %%
train = eth_rf[0:train_len]
test = eth_rf[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 5)
# test :  (86, 5)

# %%
y_train = train['Close']
X_train = train.drop(['Close'], axis=1)
y_test = test['Close']
X_test = test.drop(['Close'], axis=1)

# %%
print('TRAIN input shape : ', X_train.shape)
print('TRAIN output shape : ', y_train.shape)
print('TEST input shape : ', X_test.shape)
print('TEST output shape : ', y_test.shape)
# Out:
# TRAIN input shape :  (1700, 4)
# TRAIN output shape :  (1700,)
# TEST input shape :  (86, 4)
# TEST output shape :  (86,)

# %%
rf_model = RandomForestRegressor(n_estimators=20, max_depth=10, bootstrap=True, oob_score=True, n_jobs=-1)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20, n_jobs=-1, oob_score=True)

# %%
y_pred = rf_model.predict(X_test)
y_pred.shape
# Out:
# (86,)

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df['Date'] = y_test.index
y_pred_df = y_pred_df.set_index('Date')
y_pred_df['Close'] = y_pred_df[0]
y_pred_df.drop([0], axis=1, inplace=True)

# %%
y_pred_df.head()
# Out:
#                   Close
# Date
# 2022-07-06  1129.770302
# 2022-07-07  1203.927168
# 2022-07-08  1214.033543
# 2022-07-09  1200.562256
# 2022-07-10  1186.739124

# %%
test.head()
# Out:
#                    Open         High          Low        Close       Volume
# Date
# 2022-07-06  1134.822266  1193.636719  1116.247559  1186.973999  15373536703
# 2022-07-07  1186.960938  1246.894897  1165.623169  1237.593384  14230795894
# 2022-07-08  1237.580322  1262.885742  1200.632202  1222.506226  16315929082
# 2022-07-09  1222.306885  1228.767944  1209.377563  1216.978271   8821353104
# 2022-07-10  1216.904419  1216.904419  1157.175537  1168.401611  10984558039

# %%
plt.figure(figsize=(12,4))
plt.plot( y_train, label='Train')
plt.plot(y_test, label='Test')
plt.plot(y_pred_df['Close'], label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred_df).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_test, y_pred_df).round(2)
mape = np.round(np.mean(np.abs(y_test - y_pred_df['Close'])/y_test)*100,2)

# %%
model_param.loc[9] = ['Random Forest - No lags with ETH Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                               model        MSE    RMSE  \
# 0                                              ARMA  177127.00  420.86
# 1                                             ARIMA  177127.00  420.86
# 2                                            SARIMA  154234.99  392.73
# 3                                SARIMAX - BTC Data  246822.36  496.81
# 4        SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                 Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6      Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7     Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8  Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9        Random Forest - No lags with ETH Variables    1900.94   43.60
#
#    R-Squared   MAPE
# 0      -2.93  22.48
# 1      -2.93  22.48
# 2      -2.42  20.37
# 3      -4.48  28.44
# 4      -5.87  31.86
# 5       0.75   5.32
# 6       0.70   5.28
# 7      -6.25  29.61
# 8      -8.29  34.85
# 9       0.96   2.15

# %%
a = test.copy()
a['pred-close'] = y_pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-Random Forest - No lags with ETH Variables.xlsx')

# %%
c = a['pred-close']
c = pd.DataFrame(c)
c.columns = ['Random Forest - No lags with ETH Variables']
b = b.join(c)

# %%
# Feature importance
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": rf_model.feature_importances_})

imp_df.sort_values(by="Imp", ascending=False)
# Out:
#   Varname       Imp
# 2     Low  0.882201
# 1    High  0.115189
# 0    Open  0.002419
# 3  Volume  0.000191

# %% [markdown]
# #### Random Forest
# - with lag, ETH base data

# %%
eth_rf = eth.copy()
eth_rf = eth_rf.set_index('Date')
eth_rf.head()
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003   893249984
# 2017-11-10  320.670990  324.717987  294.541992  299.252991   885985984
# 2017-11-11  298.585999  319.453003  298.191986  314.681000   842300992
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  1613479936
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  1041889984

# %%
eth_rf['Close_lag_1'] = eth_rf['Close'].shift(1)
eth_rf['Close_lag_2'] = eth_rf['Close'].shift(2)
eth_rf['Close_lag_3'] = eth_rf['Close'].shift(3)
eth_rf['Close_lag_4'] = eth_rf['Close'].shift(4)
eth_rf['Close_lag_5'] = eth_rf['Close'].shift(5)
eth_rf['Close_lag_6'] = eth_rf['Close'].shift(6)
eth_rf['Close_lag_7'] = eth_rf['Close'].shift(7)
eth_rf.dropna(inplace=True)
eth_rf.head()
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 2017-11-16  333.442993  336.158997  323.605988  330.924011   797254016
# 2017-11-17  330.166992  334.963989  327.523010  332.394012   621732992
# 2017-11-18  331.980011  349.615997  327.687012  347.612000   649638976
# 2017-11-19  347.401001  371.290985  344.739990  354.385986  1181529984
# 2017-11-20  354.093994  372.136993  353.289001  366.730011   807027008
#
#             Close_lag_1  Close_lag_2  Close_lag_3  Close_lag_4  Close_lag_5  \
# Date
# 2017-11-16   333.356995   337.631012   316.716003   307.907990   314.681000
# 2017-11-17   330.924011   333.356995   337.631012   316.716003   307.907990
# 2017-11-18   332.394012   330.924011   333.356995   337.631012   316.716003
# 2017-11-19   347.612000   332.394012   330.924011   333.356995   337.631012
# 2017-11-20   354.385986   347.612000   332.394012   330.924011   333.356995
#
#             Close_lag_6  Close_lag_7
# Date
# 2017-11-16   299.252991   320.884003
# 2017-11-17   314.681000   299.252991
# 2017-11-18   307.907990   314.681000
# 2017-11-19   316.716003   307.907990
# 2017-11-20   337.631012   316.716003

# %%
train = eth_rf[0:train_len]
test = eth_rf[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 12)
# test :  (79, 12)

# %%
y_train = train['Close']
X_train = train.drop(['Close'], axis=1)
y_test = test['Close']
X_test = test.drop(['Close'], axis=1)

# %%
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1700,)
# (1700, 11)
# (79,)
# (79, 11)

# %%
rf_model = RandomForestRegressor(n_estimators=20, max_depth=10, bootstrap=True, oob_score=True, n_jobs=-1)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=20, n_jobs=-1, oob_score=True)

# %%
y_pred = rf_model.predict(X_test)
y_pred.shape
# Out:
# (79,)

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df['Date'] = y_test.index
y_pred_df = y_pred_df.set_index('Date')
y_pred_df['Close'] = y_pred_df[0]
y_pred_df.drop([0], axis=1, inplace=True)

# %%
plt.figure(figsize=(12,4))
plt.plot( y_train, label='Train')
plt.plot(y_test, label='Test')
plt.plot(y_pred_df['Close'], label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred_df).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_test, y_pred_df).round(2)
mape = np.round(np.mean(np.abs(y_test - y_pred_df['Close'])/y_test)*100,2)

# %%
model_param.loc[10] = ['Random Forest - With lags and ETH Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31

# %%
a = pd.DataFrame(y_pred)
a['Date'] = X_test.index
a = a.set_index('Date')
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-Random Forest - With lags and ETH Variables.xlsx')

# %%
c = a
c = pd.DataFrame(c)
c.columns = ['Random Forest - With lags and ETH Variables']
b = b.join(c)

# %% [markdown]
# #### Random Forest
# - Using Grid Search to finetune results

# %%
# Grid Search
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %%
eth_rf = eth.copy()
eth_rf = eth_rf.set_index('Date')
train = eth_rf[0:train_len]
test = eth_rf[train_len:]
y_train = train['Close']
X_train = train.drop(['Close'], axis=1)
y_test = test['Close']
X_test = test.drop(['Close'], axis=1)

# %%
print('TRAIN input shape : ', X_train.shape)
print('TRAIN output shape : ', y_train.shape)
print('TEST input shape : ', X_test.shape)
print('TEST output shape : ', y_test.shape)
# Out:
# TRAIN input shape :  (1700, 4)
# TRAIN output shape :  (1700,)
# TEST input shape :  (86, 4)
# TEST output shape :  (86,)

# %%
# Parameter tuining using GridSearch CV
params = {
    'max_depth': [8],
    'n_estimators': [20],
    'max_features': [2, 3, 4],
    'min_samples_split': [3, 5],
    'bootstrap': [True], 
    'oob_score': [True], 
    'n_jobs': [-1],
    'min_samples_leaf':  [3, 5, 7],
    'max_leaf_nodes': [150, 175],
    'random_state':[41, 90, 100]
}

# %%
rf_model = RandomForestRegressor()
y_scorer = make_scorer('neg_mean_absolute_percentage_error', greater_is_better=False)
grid_search_rf = GridSearchCV(estimator=rf_model,
                                    param_grid=params,
                                    cv=2, n_jobs=-1, verbose=1, scoring = 'neg_mean_absolute_percentage_error')
grid_search_rf.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 108 candidates, totalling 216 fits
# GridSearchCV(cv=2, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [8],
#                          'max_features': [2, 3, 4],
#                          'max_leaf_nodes': [150, 175],
#                          'min_samples_leaf': [3, 5, 7],
#                          'min_samples_split': [3, 5], 'n_estimators': [20],
#                          'n_jobs': [-1], 'oob_score': [True],
#                          'random_state': [41, 90, 100]},
#              scoring='neg_mean_absolute_percentage_error', verbose=1)

# %%
score_df = pd.DataFrame(grid_search_rf.cv_results_)
score_df.sort_values(['rank_test_score'], inplace=True)

# %%
dt_best = grid_search_rf.best_estimator_
dt_best
# Out:
# RandomForestRegressor(max_depth=8, max_features=3, max_leaf_nodes=150,
#                       min_samples_leaf=3, min_samples_split=5, n_estimators=20,
#                       n_jobs=-1, oob_score=True, random_state=90)

# %%
rf_model = dt_best
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=8, max_features=3, max_leaf_nodes=150,
#                       min_samples_leaf=3, min_samples_split=5, n_estimators=20,
#                       n_jobs=-1, oob_score=True, random_state=90)

# %%
y_pred = rf_model.predict(X_test)

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df['Date'] = y_test.index
y_pred_df = y_pred_df.set_index('Date')
y_pred_df['Close'] = y_pred_df[0]
y_pred_df.drop([0], axis=1, inplace=True)

# %%
plt.figure(figsize=(12,4))
plt.plot( y_train, label='Train')
plt.plot(y_test, label='Test')
plt.plot(y_pred_df['Close'], label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred_df).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_test, y_pred_df).round(2)
mape = np.round(np.mean(np.abs(y_test - y_pred_df['Close'])/y_test)*100,2)

# %%
model_param.loc[11] = ['RF Grid Search - No lags and ETH Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11

# %%
a = test.copy()
a['pred-close'] = y_pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-RF Grid Search - No lags and ETH Variables.xlsx')

# %%
c = a['pred-close']
c = pd.DataFrame(c)
c.columns = ['RF Grid Search - No lags and ETH Variables']
b = b.join(c)

# %%
# Feature importance
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": rf_model.feature_importances_})

imp_df.sort_values(by="Imp", ascending=False)
# Out:
#   Varname       Imp
# 2     Low  0.630894
# 1    High  0.360437
# 0    Open  0.008551
# 3  Volume  0.000117

# %% [markdown]
# #### LSTM

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
base.head(10)
# Out:
#                  Close
# Date
# 2017-11-09  320.884003
# 2017-11-10  299.252991
# 2017-11-11  314.681000
# 2017-11-12  307.907990
# 2017-11-13  316.716003
# 2017-11-14  337.631012
# 2017-11-15  333.356995
# 2017-11-16  330.924011
# 2017-11-17  332.394012
# 2017-11-18  347.612000

# %%
train = base[0:train_len]
test = base[train_len:]

# %%
look_back = 1
def dataset_generator_lstm(dataset, look_back = 1):
    dataX, dataY = [], []
    
    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back)]
        dataX.append(window_size_x)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(train.Close)

testX, testY = dataset_generator_lstm(test.Close)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testX: ", testX.shape)
print("testY", testY.shape)
# Out:
# trainX:  (1699, 1)
# trainY:  (1699,)
# testX:  (85, 1)
# testY (85,)

# %% [markdown]
# #### Reshaping input to be a 3D Tensor of [samples, time steps, features] for LSTM

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1 ))

print("Shape of trainX: ", trainX.shape)
print("Shape of testX: ", testX.shape)
# Out:
# Shape of trainX:  (1699, 1, 1)
# Shape of testX:  (85, 1, 1)

# %%
trainX
# Out:
# array([[[ 320.884003]],
#
#        [[ 299.252991]],
#
#        [[ 314.681   ]],
#
#        ...,
#
#        [[1066.512817]],
#
#        [[1073.766968]],
#
#        [[1151.059082]]])

# %%
print("timesteps in input_shape : ", trainX.shape[1])
print("n_features : ", trainX.shape[2])
# Out:
# timesteps in input_shape :  1
# n_features :  1

# %%
model = Sequential()
model.add(LSTM(64, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(32, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(16, activation = 'relu', return_sequences=False))
#model.add(Dropout(0.2))
model.add(Dense(trainX.shape[1]))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 64)             16896
#
#  lstm_1 (LSTM)               (None, 1, 32)             12416
#
#  lstm_2 (LSTM)               (None, 16)                3136
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 32,465
# Trainable params: 32,465
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
checkpoint = ModelCheckpoint(filepath='best_model.hdf5',
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]

history = model.fit(trainX, trainY, 
                    epochs=500, 
                    batch_size=32, 
                    verbose='auto', 
                    shuffle=False, 
                    validation_data=(testX, testY),
                    callbacks=callbacks)
# Out:
# Epoch 1/500
# 51/54 [===========================>..] - ETA: 0s - loss: 2427620.5000
# Epoch 1: val_loss improved from inf to 2006656.25000, saving model to best_model.hdf5
# 54/54 [==============================] - 3s 12ms/step - loss: 2443699.5000 - val_loss: 2006656.2500
# Epoch 2/500
# 45/54 [========================>.....] - ETA: 0s - loss: 505610.9375
# Epoch 2: val_loss improved from 2006656.25000 to 52905.60547, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 638190.1250 - val_loss: 52905.6055
# Epoch 3/500
# 36/54 [===================>..........] - ETA: 0s - loss: 2413.7520
# Epoch 3: val_loss improved from 52905.60547 to 12462.03223, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 31482.1016 - val_loss: 12462.0322
# Epoch 4/500
# 43/54 [======================>.......] - ETA: 0s - loss: 17828.1738
# Epoch 4: val_loss improved from 12462.03223 to 9519.52832, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 25874.4688 - val_loss: 9519.5283
# Epoch 5/500
# 39/54 [====================>.........] - ETA: 0s - loss: 4392.9634
# Epoch 5: val_loss did not improve from 9519.52832
# 54/54 [==============================] - 0s 4ms/step - loss: 17250.8750 - val_loss: 11749.0605
# Epoch 6/500
# 52/54 [===========================>..] - ETA: 0s - loss: 16470.3730
# Epoch 6: val_loss did not improve from 9519.52832
# 54/54 [==============================] - 0s 4ms/step - loss: 16342.7432 - val_loss: 10135.8350
# Epoch 7/500
# 51/54 [===========================>..] - ETA: 0s - loss: 12301.5928
# Epoch 7: val_loss did not improve from 9519.52832
# 54/54 [==============================] - 0s 4ms/step - loss: 12190.7334 - val_loss: 10358.0459
# Epoch 8/500
# 47/54 [=========================>....] - ETA: 0s - loss: 9117.6543
# Epoch 8: val_loss improved from 9519.52832 to 7503.71240, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 9896.4512 - val_loss: 7503.7124
# Epoch 9/500
# 53/54 [============================>.] - ETA: 0s - loss: 6725.6821
# Epoch 9: val_loss improved from 7503.71240 to 6040.58008, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 6718.9595 - val_loss: 6040.5801
# Epoch 10/500
# 51/54 [===========================>..] - ETA: 0s - loss: 6709.7173
# Epoch 10: val_loss improved from 6040.58008 to 5638.46484, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 6862.2515 - val_loss: 5638.4648
# Epoch 11/500
# 49/54 [==========================>...] - ETA: 0s - loss: 6201.2773
# Epoch 11: val_loss improved from 5638.46484 to 5569.12988, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 6491.5493 - val_loss: 5569.1299
# Epoch 12/500
# 50/54 [==========================>...] - ETA: 0s - loss: 6386.2432
# Epoch 12: val_loss improved from 5569.12988 to 5554.81445, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 4ms/step - loss: 6584.5610 - val_loss: 5554.8145
# Epoch 13/500
# 51/54 [===========================>..] - ETA: 0s - loss: 6438.7285
# Epoch 13: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 6569.2344 - val_loss: 5558.0801
# Epoch 14/500
# 54/54 [==============================] - ETA: 0s - loss: 6605.5835
# Epoch 14: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 6605.5835 - val_loss: 5556.6450
# Epoch 15/500
# 37/54 [===================>..........] - ETA: 0s - loss: 876.4565
# Epoch 15: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 6610.2378 - val_loss: 5557.1514
# Epoch 16/500
# 52/54 [===========================>..] - ETA: 0s - loss: 6659.8291
# Epoch 16: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 4ms/step - loss: 6650.4360 - val_loss: 5558.3120
# Epoch 17/500
# 45/54 [========================>.....] - ETA: 0s - loss: 5007.8145
# Epoch 17: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 4ms/step - loss: 6668.4609 - val_loss: 5560.3223
# Epoch 18/500
# 53/54 [============================>.] - ETA: 0s - loss: 6713.3569
# Epoch 18: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 6705.2275 - val_loss: 5566.0542
# Epoch 19/500
# 52/54 [===========================>..] - ETA: 0s - loss: 6712.7700
# Epoch 19: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 4ms/step - loss: 6701.7300 - val_loss: 5567.9814
# Epoch 20/500
# 36/54 [===================>..........] - ETA: 0s - loss: 616.8931
# Epoch 20: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 7217.1152 - val_loss: 5596.9473
# Epoch 21/500
# 36/54 [===================>..........] - ETA: 0s - loss: 626.9543
# Epoch 21: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 7001.4409 - val_loss: 5585.5649
# Epoch 22/500
# 54/54 [==============================] - ETA: 0s - loss: 6541.0132
# Epoch 22: val_loss did not improve from 5554.81445
# 54/54 [==============================] - 0s 3ms/step - loss: 6541.0132 - val_loss: 5655.3027

# %%
result = model.predict(testX, batch_size=1, verbose=0)

# %%
result.shape
# Out:
# (85, 1)

# %%
result
# Out:
# array([[1186.4977],
#        [1237.032 ],
#        [1221.9701],
#        [1216.4514],
#        [1167.9567],
#        [1096.9114],
#        [1037.9656],
#        [1113.2344],
#        [1191.0422],
#        [1232.5751],
#        [1351.8711],
#        [1337.9039],
#        [1577.5815],
#        [1541.8989],
#        [1519.1628],
#        [1575.6163],
#        [1536.3384],
#        [1548.2108],
#        [1598.3052],
#        [1444.4716],
#        [1440.901 ],
#        [1634.9995],
#        [1724.0844],
#        [1726.0201],
#        [1694.6354],
#        [1680.2076],
#        [1633.9641],
#        [1631.7174],
#        [1617.6704],
#        [1607.0198],
#        [1730.8594],
#        [1690.3313],
#        [1698.0112],
#        [1774.048 ],
#        [1701.6791],
#        [1850.1462],
#        [1879.578 ],
#        [1955.4722],
#        [1979.5216],
#        [1935.0623],
#        [1902.5433],
#        [1876.4985],
#        [1831.4348],
#        [1845.4193],
#        [1611.7931],
#        [1575.8701],
#        [1618.1141],
#        [1621.2957],
#        [1661.4918],
#        [1655.7906],
#        [1695.1223],
#        [1506.7659],
#        [1490.4059],
#        [1429.6608],
#        [1551.9442],
#        [1522.7948],
#        [1552.5906],
#        [1585.0277],
#        [1576.0865],
#        [1555.7731],
#        [1576.507 ],
#        [1615.9819],
#        [1560.6406],
#        [1628.6837],
#        [1634.1157],
#        [1717.7123],
#        [1774.7345],
#        [1760.3552],
#        [1712.4014],
#        [1579.6481],
#        [1633.5242],
#        [1470.7374],
#        [1431.5579],
#        [1468.7891],
#        [1334.6028],
#        [1376.744 ],
#        [1323.6804],
#        [1252.0208],
#        [1326.9668],
#        [1327.5453],
#        [1317.2964],
#        [1293.5599],
#        [1334.594 ],
#        [1329.4103],
#        [1336.6812]], dtype=float32)

# %%
testY.shape
# Out:
# (85,)

# %%
pred_df = pd.DataFrame(result, columns = ['Pred_Close'])
pred_df.index = test[look_back:].index
pred_df.tail()
# Out:
#              Pred_Close
# Date
# 2022-09-25  1317.296387
# 2022-09-26  1293.559937
# 2022-09-27  1334.593994
# 2022-09-28  1329.410278
# 2022-09-29  1336.681152

# %%
a = test.copy()
a['pred-close'] = y_pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-LSTM - 1 variable and 1 look back.xlsx')

# %%
c = a['pred-close']
c = pd.DataFrame(c)
c.columns = ['LSTM - 1 variable and 1 look back']
b = b.join(c)

# %%
plt.figure(figsize=(12,4))
plt.plot( train, label='Train')
plt.plot(test, label='Test')
plt.plot(pred_df['Pred_Close'], label='LSTM')
plt.legend(loc='best')
plt.title('LSTM')
plt.show()

# %%
mse = mean_squared_error(test[look_back:], pred_df['Pred_Close']).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test[look_back:], pred_df['Pred_Close']).round(2)
mape = np.round(np.mean(np.abs(test.Close[look_back:] - pred_df['Pred_Close'])/test.Close[look_back:])*100,2)

# %%
model_param.loc[12] = ['LSTM - 1 variable and 1 look back', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52

# %% [markdown]
# #### LSTM
# - Lookback 7

# %%
train = base[0:train_len]
test = base[train_len:]

# %%
look_back = 7
def dataset_generator_lstm(dataset, look_back = 7):
    dataX, dataY = [], []
    
    for i in range(len(dataset) - look_back):
        window_size_x = dataset[i:(i + look_back)]
        dataX.append(window_size_x)
        dataY.append(dataset[i + look_back])
    return np.array(dataX), np.array(dataY)

trainX, trainY = dataset_generator_lstm(train.Close)

testX, testY = dataset_generator_lstm(test.Close)

print("trainX: ", trainX.shape)
print("trainY: ", trainY.shape)
print("testX: ", testX.shape)
print("testY", testY.shape)
# Out:
# trainX:  (1693, 7)
# trainY:  (1693,)
# testX:  (79, 7)
# testY (79,)

# %% [markdown]
# #### Reshaping input to be a 3D Tensor of [samples, time steps, features] for LSTM

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1 ))

print("Shape of trainX: ", trainX.shape)
print("Shape of testX: ", testX.shape)
# Out:
# Shape of trainX:  (1693, 7, 1)
# Shape of testX:  (79, 7, 1)

# %%
print("timesteps in input_shape : ", trainX.shape[1])
print("n_features : ", trainX.shape[2])
# Out:
# timesteps in input_shape :  7
# n_features :  1

# %%
model = Sequential()
model.add(LSTM(128, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(64, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(32, activation = 'relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainX.shape[1]))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 7, 128)            66560
#
#  lstm_4 (LSTM)               (None, 7, 64)             49408
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 7)                 231
#
# =================================================================
# Total params: 128,615
# Trainable params: 128,615
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
checkpoint = ModelCheckpoint(filepath='best_model.hdf5',
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]

history = model.fit(trainX, trainY, 
                    epochs=500, 
                    batch_size=32, 
                    verbose='auto', 
                    shuffle=False, 
                    validation_data=(testX, testY),
                    callbacks=callbacks)
# Out:
# Epoch 1/500
# 50/53 [===========================>..] - ETA: 0s - loss: 779522.2500
# Epoch 1: val_loss improved from inf to 237543.79688, saving model to best_model.hdf5
# 53/53 [==============================] - 3s 19ms/step - loss: 816344.1250 - val_loss: 237543.7969
# Epoch 2/500
# 52/53 [============================>.] - ETA: 0s - loss: 661469.2500
# Epoch 2: val_loss did not improve from 237543.79688
# 53/53 [==============================] - 1s 11ms/step - loss: 657582.1250 - val_loss: 276024.1875
# Epoch 3/500
# 51/53 [===========================>..] - ETA: 0s - loss: 327073.0938
# Epoch 3: val_loss improved from 237543.79688 to 73326.21094, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 12ms/step - loss: 328520.0625 - val_loss: 73326.2109
# Epoch 4/500
# 52/53 [============================>.] - ETA: 0s - loss: 298500.5000
# Epoch 4: val_loss improved from 73326.21094 to 50686.86719, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 12ms/step - loss: 296491.3438 - val_loss: 50686.8672
# Epoch 5/500
# 48/53 [==========================>...] - ETA: 0s - loss: 236867.9844
# Epoch 5: val_loss did not improve from 50686.86719
# 53/53 [==============================] - 1s 11ms/step - loss: 266923.8438 - val_loss: 94911.3828
# Epoch 6/500
# 47/53 [=========================>....] - ETA: 0s - loss: 185299.9219
# Epoch 6: val_loss improved from 50686.86719 to 45337.55469, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 226298.2656 - val_loss: 45337.5547
# Epoch 7/500
# 48/53 [==========================>...] - ETA: 0s - loss: 198136.5156
# Epoch 7: val_loss did not improve from 45337.55469
# 53/53 [==============================] - 1s 11ms/step - loss: 225881.9062 - val_loss: 55609.4609
# Epoch 8/500
# 51/53 [===========================>..] - ETA: 0s - loss: 234706.6406
# Epoch 8: val_loss did not improve from 45337.55469
# 53/53 [==============================] - 1s 12ms/step - loss: 235563.5938 - val_loss: 57587.5938
# Epoch 9/500
# 53/53 [==============================] - ETA: 0s - loss: 232781.8281
# Epoch 9: val_loss did not improve from 45337.55469
# 53/53 [==============================] - 1s 11ms/step - loss: 232781.8281 - val_loss: 65575.1016
# Epoch 10/500
# 50/53 [===========================>..] - ETA: 0s - loss: 195766.2188
# Epoch 10: val_loss improved from 45337.55469 to 28678.51953, saving model to best_model.hdf5
# 53/53 [==============================] - 1s 11ms/step - loss: 206941.5625 - val_loss: 28678.5195
# Epoch 11/500
# 52/53 [============================>.] - ETA: 0s - loss: 187806.2500
# Epoch 11: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 186542.0625 - val_loss: 47344.7188
# Epoch 12/500
# 48/53 [==========================>...] - ETA: 0s - loss: 148268.1875
# Epoch 12: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 13ms/step - loss: 166877.0312 - val_loss: 64196.3555
# Epoch 13/500
# 47/53 [=========================>....] - ETA: 0s - loss: 179850.0625
# Epoch 13: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 11ms/step - loss: 240849.5938 - val_loss: 166108.0938
# Epoch 14/500
# 53/53 [==============================] - ETA: 0s - loss: 162362.7500
# Epoch 14: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 162362.7500 - val_loss: 86017.1641
# Epoch 15/500
# 52/53 [============================>.] - ETA: 0s - loss: 189561.4062
# Epoch 15: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 189812.2969 - val_loss: 78785.8828
# Epoch 16/500
# 48/53 [==========================>...] - ETA: 0s - loss: 155560.0312
# Epoch 16: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 11ms/step - loss: 174631.6250 - val_loss: 95825.7500
# Epoch 17/500
# 53/53 [==============================] - ETA: 0s - loss: 152168.2656
# Epoch 17: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 152168.2656 - val_loss: 78042.5938
# Epoch 18/500
# 47/53 [=========================>....] - ETA: 0s - loss: 115757.2969
# Epoch 18: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 145479.5938 - val_loss: 33650.5742
# Epoch 19/500
# 47/53 [=========================>....] - ETA: 0s - loss: 111605.9062
# Epoch 19: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 135713.1875 - val_loss: 61058.9414
# Epoch 20/500
# 53/53 [==============================] - ETA: 0s - loss: 164353.1719
# Epoch 20: val_loss did not improve from 28678.51953
# 53/53 [==============================] - 1s 10ms/step - loss: 164353.1719 - val_loss: 60962.9609

# %%
result = model.predict(testX, batch_size=1, verbose=0)

# %%
result.shape
# Out:
# (79, 7)

# %%
testY.shape
# Out:
# (79,)

# %%
pred_df = pd.DataFrame(result, columns = ['Pred_Close', 'lag2', 'lag3', 'lag4', 'lag5', 'lag6', 'lag7'])
pred_df.index = test[look_back:].index
pred_df.tail()
# Out:
#              Pred_Close         lag2         lag3         lag4         lag5  \
# Date
# 2022-09-25  1303.060913  1284.842773  1299.437744  1319.527588  1358.533081
# 2022-09-26  1294.930420  1277.926636  1292.057251  1309.261108  1349.096924
# 2022-09-27  1277.290161  1261.098022  1274.568970  1288.695312  1330.973022
# 2022-09-28  1272.747314  1256.150635  1269.440430  1284.173584  1326.684937
# 2022-09-29  1292.936401  1275.623535  1289.472778  1307.160034  1347.733398
#
#                    lag6         lag7
# Date
# 2022-09-25  1353.153931  1357.355835
# 2022-09-26  1352.598511  1351.364990
# 2022-09-27  1334.309082  1331.489136
# 2022-09-28  1321.625610  1323.876587
# 2022-09-29  1344.844604  1346.677979

# %%
plt.figure(figsize=(12,4))
plt.plot( train, label='Train')
plt.plot(test, label='Test')
plt.plot(pred_df['Pred_Close'], label='LSTM')
plt.legend(loc='best')
plt.title('LSTM')
plt.show()

# %%
mse = mean_squared_error(test[look_back:], pred_df['Pred_Close']).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test[look_back:], pred_df['Pred_Close']).round(2)
mape = np.round(np.mean(np.abs(test.Close[look_back:] - pred_df['Pred_Close'])/test.Close[look_back:])*100,2)

# %%
model_param.loc[13] = ['LSTM - 1 variable and 7 look back', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52
# 13       0.18   8.75

# %%
a = pred_df['Pred_Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-LSTM - 1 variable and 7 look back.xlsx')

# %%
c = a
c = pd.DataFrame(c)
c.columns = ['LSTM - 1 variable and 7 look back']
b = b.join(c)

# %% [markdown]
# #### LSTM with data from Bitcoin

# %%
train = rf_crypto[0:train_len]
test = rf_crypto[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 10)
# test :  (86, 10)

# %%
train = train[['Close', 
               'Close_btc', 
               'volume_fi', 
               'volume_nvi', 
               'volatility_ui', 
               'trend_macd_signal', 
               'trend_mass_index', 
               'trend_dpo', 
               'trend_kst_sig', 
               'trend_kst_diff']]
test = test[['Close', 
               'Close_btc', 
               'volume_fi', 
               'volume_nvi', 
               'volatility_ui', 
               'trend_macd_signal', 
               'trend_mass_index', 
               'trend_dpo', 
               'trend_kst_sig', 
               'trend_kst_diff']]

# %%
scaler = QuantileTransformer(output_distribution='normal')
vars_to_scale = ['Close',
                'Close_btc',
                'volume_fi',
                'volume_nvi',
                'volatility_ui',
                'trend_macd_signal',
                'trend_mass_index',
                'trend_dpo',
                'trend_kst_sig',
                'trend_kst_diff']

# %%
train_sc = train.copy()
test_sc = test.copy()

# %%
train_sc[vars_to_scale] = scaler.fit_transform(train[vars_to_scale])
test_sc[vars_to_scale] = scaler.transform(test[vars_to_scale])

# %%
train_sc.describe()
# Out:
#              Close    Close_btc    volume_fi    volume_nvi  volatility_ui  \
# count  1700.000000  1700.000000  1700.000000  1.700000e+03    1700.000000
# mean     -0.000266    -0.000064    -0.000025  9.945859e-05      -0.017303
# std       1.012252     1.011808     1.011301  1.011494e+00       1.077993
# min      -5.199338    -5.199338    -5.199338 -5.199338e+00      -5.199338
# 25%      -0.675552    -0.674498    -0.674382 -6.767490e-01      -0.675086
# 50%       0.000573     0.000799     0.000227  6.960578e-17       0.000094
# 75%       0.674422     0.674475     0.674740  6.742801e-01       0.676154
# max       5.199338     5.199338     5.199338  5.199338e+00       5.199338
#
#        trend_macd_signal  trend_mass_index    trend_dpo  trend_kst_sig  \
# count        1700.000000       1700.000000  1700.000000    1700.000000
# mean            0.000081         -0.000028     0.000095      -0.000013
# std             1.012457          1.011441     1.012060       1.011755
# min            -5.199338         -5.199338    -5.199338      -5.199338
# 25%            -0.673960         -0.674250    -0.674735      -0.674160
# 50%            -0.000407          0.000073     0.000065       0.000171
# 75%             0.674551          0.674237     0.673896       0.675225
# max             5.199338          5.199338     5.199338       5.199338
#
#        trend_kst_diff
# count     1700.000000
# mean         0.000086
# std          1.011927
# min         -5.199338
# 25%         -0.674747
# 50%         -0.000565
# 75%          0.674279
# max          5.199338

# %%
trainX = []
trainY = []
testX = []
testY = []

# %%
n_future = 1
n_past = 2

for i in range (n_past, len(train_sc) - n_future +1):
    trainX.append(train_sc[i - n_past : i])
    trainY.append(train_sc[i + n_future - 1 : i + n_future].Close)
for i in range (n_past, len(test_sc) - n_future +1):
    testX.append(test_sc[i - n_past : i])
    testY.append(test_sc[i + n_future - 1 : i + n_future].Close)

# %%
trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)

# %%
print (trainX.shape)
print (trainY.shape)
print (testX.shape)
print (testY.shape)
# Out:
# (1698, 2, 10)
# (1698, 1)
# (84, 2, 10)
# (84, 1)

# %%
model = Sequential()
model.add(LSTM(128, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(64, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(32, activation = 'relu', return_sequences=False))
#model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 2, 128)            71168
#
#  lstm_7 (LSTM)               (None, 2, 64)             49408
#
#  lstm_8 (LSTM)               (None, 32)                12416
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 133,025
# Trainable params: 133,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

checkpoint = ModelCheckpoint(filepath='best_model.hdf5',
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]

history = model.fit(trainX, trainY, 
                    epochs=500, 
                    batch_size=32, 
                    verbose='auto', 
                    shuffle=False, 
                    validation_data=(testX, testY),
                    callbacks=callbacks)
# Out:
# Epoch 1/500
# 52/54 [===========================>..] - ETA: 0s - loss: 1.0532
# Epoch 1: val_loss improved from inf to 0.31350, saving model to best_model.hdf5
# 54/54 [==============================] - 3s 12ms/step - loss: 1.0372 - val_loss: 0.3135
# Epoch 2/500
# 51/54 [===========================>..] - ETA: 0s - loss: 0.8037
# Epoch 2: val_loss improved from 0.31350 to 0.04105, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 6ms/step - loss: 0.7781 - val_loss: 0.0411
# Epoch 3/500
# 53/54 [============================>.] - ETA: 0s - loss: 0.6648
# Epoch 3: val_loss did not improve from 0.04105
# 54/54 [==============================] - 0s 5ms/step - loss: 0.6640 - val_loss: 0.1196
# Epoch 4/500
# 47/54 [=========================>....] - ETA: 0s - loss: 0.4656
# Epoch 4: val_loss did not improve from 0.04105
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4295 - val_loss: 0.0463
# Epoch 5/500
# 44/54 [=======================>......] - ETA: 0s - loss: 0.2590
# Epoch 5: val_loss did not improve from 0.04105
# 54/54 [==============================] - 0s 5ms/step - loss: 0.2733 - val_loss: 0.0722
# Epoch 6/500
# 43/54 [======================>.......] - ETA: 0s - loss: 0.1277
# Epoch 6: val_loss improved from 0.04105 to 0.01590, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 5ms/step - loss: 0.1499 - val_loss: 0.0159
# Epoch 7/500
# 43/54 [======================>.......] - ETA: 0s - loss: 0.1192
# Epoch 7: val_loss did not improve from 0.01590
# 54/54 [==============================] - 0s 5ms/step - loss: 0.1311 - val_loss: 0.0393
# Epoch 8/500
# 43/54 [======================>.......] - ETA: 0s - loss: 0.0753
# Epoch 8: val_loss improved from 0.01590 to 0.01022, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0854 - val_loss: 0.0102
# Epoch 9/500
# 43/54 [======================>.......] - ETA: 0s - loss: 0.0697
# Epoch 9: val_loss did not improve from 0.01022
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0761 - val_loss: 0.0121
# Epoch 10/500
# 53/54 [============================>.] - ETA: 0s - loss: 0.0656
# Epoch 10: val_loss did not improve from 0.01022
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0655 - val_loss: 0.0113
# Epoch 11/500
# 45/54 [========================>.....] - ETA: 0s - loss: 0.0509
# Epoch 11: val_loss improved from 0.01022 to 0.00604, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0542 - val_loss: 0.0060
# Epoch 12/500
# 45/54 [========================>.....] - ETA: 0s - loss: 0.0476
# Epoch 12: val_loss did not improve from 0.00604
# 54/54 [==============================] - 0s 4ms/step - loss: 0.0507 - val_loss: 0.0067
# Epoch 13/500
# 43/54 [======================>.......] - ETA: 0s - loss: 0.0437
# Epoch 13: val_loss improved from 0.00604 to 0.00528, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0467 - val_loss: 0.0053
# Epoch 14/500
# 44/54 [=======================>......] - ETA: 0s - loss: 0.0402
# Epoch 14: val_loss improved from 0.00528 to 0.00448, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0426 - val_loss: 0.0045
# Epoch 15/500
# 47/54 [=========================>....] - ETA: 0s - loss: 0.0423
# Epoch 15: val_loss improved from 0.00448 to 0.00357, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0390 - val_loss: 0.0036
# Epoch 16/500
# 51/54 [===========================>..] - ETA: 0s - loss: 0.0374
# Epoch 16: val_loss improved from 0.00357 to 0.00274, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0361 - val_loss: 0.0027
# Epoch 17/500
# 54/54 [==============================] - ETA: 0s - loss: 0.0340
# Epoch 17: val_loss improved from 0.00274 to 0.00225, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0340 - val_loss: 0.0022
# Epoch 18/500
# 53/54 [============================>.] - ETA: 0s - loss: 0.0321
# Epoch 18: val_loss did not improve from 0.00225
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0024
# Epoch 19/500
# 53/54 [============================>.] - ETA: 0s - loss: 0.0296
# Epoch 19: val_loss did not improve from 0.00225
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0295 - val_loss: 0.0023
# Epoch 20/500
# 48/54 [=========================>....] - ETA: 0s - loss: 0.0293
# Epoch 20: val_loss did not improve from 0.00225
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0276 - val_loss: 0.0028
# Epoch 21/500
# 49/54 [==========================>...] - ETA: 0s - loss: 0.0279
# Epoch 21: val_loss improved from 0.00225 to 0.00134, saving model to best_model.hdf5
# 54/54 [==============================] - 0s 6ms/step - loss: 0.0262 - val_loss: 0.0013
# Epoch 22/500
# 41/54 [=====================>........] - ETA: 0s - loss: 0.0221
# Epoch 22: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0250 - val_loss: 0.0028
# Epoch 23/500
# 44/54 [=======================>......] - ETA: 0s - loss: 0.0227
# Epoch 23: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0262 - val_loss: 0.0015
# Epoch 24/500
# 53/54 [============================>.] - ETA: 0s - loss: 0.0277
# Epoch 24: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0277 - val_loss: 0.0052
# Epoch 25/500
# 44/54 [=======================>......] - ETA: 0s - loss: 0.0200
# Epoch 25: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0264 - val_loss: 0.0035
# Epoch 26/500
# 41/54 [=====================>........] - ETA: 0s - loss: 0.0234
# Epoch 26: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0277 - val_loss: 0.0035
# Epoch 27/500
# 54/54 [==============================] - ETA: 0s - loss: 0.0317
# Epoch 27: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0049
# Epoch 28/500
# 54/54 [==============================] - ETA: 0s - loss: 0.0339
# Epoch 28: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0339 - val_loss: 0.0053
# Epoch 29/500
# 45/54 [========================>.....] - ETA: 0s - loss: 0.0319
# Epoch 29: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0365 - val_loss: 0.0027
# Epoch 30/500
# 41/54 [=====================>........] - ETA: 0s - loss: 0.0540
# Epoch 30: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0599 - val_loss: 0.0197
# Epoch 31/500
# 44/54 [=======================>......] - ETA: 0s - loss: 0.0278
# Epoch 31: val_loss did not improve from 0.00134
# 54/54 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0042

# %%
result_sc = model.predict(testX)
result_sc.shape
# Out:
# 3/3 [==============================] - 0s 0s/step
# (84, 1)

# %%
result_sc = np.repeat(result_sc, 10, axis=-1)
result_sc.shape
# Out:
# (84, 10)

# %%
result = scaler.inverse_transform(result_sc)

# %%
pred_dates = test.index[:-n_past]
pred_dates.shape
# Out:
# (84,)

# %%
result_df = pd.DataFrame(result)
pred_df = pd.DataFrame(result, columns = ['Close', 
                'Close_btc',
                'volume_fi',
                'volume_nvi',
                'volatility_ui',
                'trend_macd_signal',
                'trend_mass_index',
                'trend_dpo',
                'trend_kst_sig',
                'trend_kst_diff'])
pred_df.index = pred_dates
pred_df.head()
# Out:
#                   Close     Close_btc     volume_fi  volume_nvi  \
# Date
# 2022-07-06  1284.557495  29728.406250  1.171328e+12  426.493958
# 2022-07-07  1387.303345  30417.361328  1.290041e+12  428.768463
# 2022-07-08  1518.564697  31478.115234  1.369698e+12  430.817657
# 2022-07-09  1462.785767  31173.439453  1.337740e+12  430.175049
# 2022-07-10  1348.956665  30016.255859  1.252273e+12  426.877319
#
#             volatility_ui  trend_macd_signal  trend_mass_index   trend_dpo  \
# Date
# 2022-07-06      11.341607         292.286011         25.593058  251.997879
# 2022-07-07      11.453928         312.190338         25.618111  263.217133
# 2022-07-08      11.566251         320.717255         25.639231  269.031799
# 2022-07-09      11.545655         316.586975         25.628275  266.600861
# 2022-07-10      11.400779         298.260712         25.600208  256.665619
#
#             trend_kst_sig  trend_kst_diff
# Date
# 2022-07-06     106.666077       22.692467
# 2022-07-07     110.719360       23.157150
# 2022-07-08     113.070366       23.773182
# 2022-07-09     111.933762       23.604214
# 2022-07-10     107.929588       22.821358

# %%
plt.figure(figsize=(12,4))
plt.plot( train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(pred_df['Close'], label='LSTM')
plt.legend(loc='best')
plt.title('LSTM')
plt.show()

# %%
mse = mean_squared_error(test['Close'][:-n_past], pred_df['Close']).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'][:-n_past], pred_df['Close']).round(2)
mape = np.round(np.mean(np.abs(test['Close'][:-n_past] - pred_df['Close'])/test['Close'][:-n_past])*100,2)

# %%
model_param.loc[14] = ['LSTM - BTC FE variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
# 14                           LSTM - BTC FE variables   18038.48  134.31
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52
# 13       0.18   8.75
# 14       0.60   7.69

# %%
a = pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-LSTM - BTC FE variables.xlsx')

# %%
c = a
c = pd.DataFrame(c)
c.columns = ['LSTM - BTC FE variables']
b = b.join(c)

# %% [markdown]
# #### LSTM on FE variables of ETH

# %%
eth_fe = eth.copy()
eth_fe.head()
# Out:
#         Date        Open        High         Low       Close      Volume
# 0 2017-11-09  308.644989  329.451996  307.056000  320.884003   893249984
# 1 2017-11-10  320.670990  324.717987  294.541992  299.252991   885985984
# 2 2017-11-11  298.585999  319.453003  298.191986  314.681000   842300992
# 3 2017-11-12  314.690002  319.153015  298.513000  307.907990  1613479936
# 4 2017-11-13  307.024994  328.415009  307.024994  316.716003  1041889984

# %%
add_all_ta_features(eth_fe, 
                    open='Open', 
                    high='High', 
                    low='Low', 
                    close='Close', 
                    volume='Volume', 
                    fillna=True)
eth_fe.head()
# Out:
#         Date        Open        High         Low       Close      Volume  \
# 0 2017-11-09  308.644989  329.451996  307.056000  320.884003   893249984
# 1 2017-11-10  320.670990  324.717987  294.541992  299.252991   885985984
# 2 2017-11-11  298.585999  319.453003  298.191986  314.681000   842300992
# 3 2017-11-12  314.690002  319.153015  298.513000  307.907990  1613479936
# 4 2017-11-13  307.024994  328.415009  307.024994  316.716003  1041889984
#
#      volume_adi  volume_obv  volume_cmf     volume_fi  ...  momentum_ppo  \
# 0  2.097921e+08   893249984    0.234864  0.000000e+00  ...      0.000000
# 1 -3.995581e+08     7264000   -0.224567 -1.916477e+10  ...     -0.540448
# 2  6.463651e+07   849564992    0.024656 -1.457052e+10  ...     -0.572861
# 3 -7.998521e+07  -763914944   -0.018887 -1.405017e+10  ...     -0.762634
# 4 -1.777931e+08   277975040   -0.033693 -1.073201e+10  ...     -0.680827
#
#    momentum_ppo_signal  momentum_ppo_hist  momentum_pvo  momentum_pvo_signal  \
# 0             0.000000           0.000000      0.000000             0.000000
# 1            -0.108090          -0.432358     -0.064911            -0.012982
# 2            -0.201044          -0.371817     -0.507515            -0.111889
# 3            -0.313362          -0.449272      5.726172             1.055723
# 4            -0.386855          -0.293972      5.641101             1.972799
#
#    momentum_pvo_hist  momentum_kama  others_dr  others_dlr  others_cr
# 0           0.000000     320.884003 -71.374722    0.000000   0.000000
# 1          -0.051928     312.601257  -6.741069   -6.979036  -6.741069
# 2          -0.395627     313.466027   5.155507    5.027009  -1.933098
# 3           4.670449     311.151593  -2.152342   -2.175842  -4.043833
# 4           3.668302     313.358264   2.860599    2.820448  -1.298912
#
# [5 rows x 92 columns]

# %%
eth_fe.shape
# Out:
# (1786, 92)

# %%
y = eth_fe['Close']
X = eth_fe.drop('Close', axis=1)

# %%
X.shape
# Out:
# (1786, 91)

# %%
constant = DropConstantFeatures(tol=0.600)
constant.fit(X)
# Out:
# DropConstantFeatures(tol=0.6)

# %%
len(constant.features_to_drop_)
# Out:
# 6

# %%
constant.features_to_drop_
# Out:
# ['volatility_bbhi',
#  'volatility_bbli',
#  'volatility_kchi',
#  'volatility_kcli',
#  'trend_psar_up_indicator',
#  'trend_psar_down_indicator']

# %%
X.drop(constant.features_to_drop_, axis=1, inplace=True)
X.shape
# Out:
# (1786, 85)

# %%
duplicates = DropDuplicateFeatures()
duplicates.fit(X)

len(duplicates.features_to_drop_)
# Out:
# 0

# %%
correlated = DropCorrelatedFeatures(variables=None, method='pearson', threshold=0.7)
correlated.fit(X)
# Out:
# DropCorrelatedFeatures(threshold=0.7)

# %%
len(correlated.features_to_drop_)
# Out:
# 59

# %%
l = list(correlated.features_to_drop_)

# %%
X.drop(l, axis=1, inplace=True)
X.shape
# Out:
# (1786, 26)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1786 non-null   datetime64[ns]
#  1   Open               1786 non-null   float64
#  2   Volume             1786 non-null   int64
#  3   volume_cmf         1786 non-null   float64
#  4   volume_fi          1786 non-null   float64
#  5   volume_em          1786 non-null   float64
#  6   volume_sma_em      1786 non-null   float64
#  7   volume_vpt         1786 non-null   float64
#  8   volume_mfi         1786 non-null   float64
#  9   volume_nvi         1786 non-null   float64
#  10  volatility_bbw     1786 non-null   float64
#  11  volatility_kcp     1786 non-null   float64
#  12  volatility_ui      1786 non-null   float64
#  13  trend_macd         1786 non-null   float64
#  14  trend_trix         1786 non-null   float64
#  15  trend_mass_index   1786 non-null   float64
#  16  trend_dpo          1786 non-null   float64
#  17  trend_kst          1786 non-null   float64
#  18  trend_kst_diff     1786 non-null   float64
#  19  trend_stc          1786 non-null   float64
#  20  trend_adx          1786 non-null   float64
#  21  trend_aroon_up     1786 non-null   float64
#  22  trend_aroon_down   1786 non-null   float64
#  23  momentum_pvo       1786 non-null   float64
#  24  momentum_pvo_hist  1786 non-null   float64
#  25  others_dr          1786 non-null   float64
# dtypes: datetime64[ns](1), float64(24), int64(1)
# memory usage: 362.9 KB

# %%
smart_correlated = SmartCorrelatedSelection(variables=None, 
                                            method='pearson', 
                                            threshold=0.7, 
                                            missing_values='ignore', 
                                            selection_method='missing_values', 
                                            estimator=None, 
                                            scoring='roc_auc', 
                                            cv=3)
smart_correlated.fit(X)
# Out:
# SmartCorrelatedSelection(threshold=0.7)

# %%
smart_correlated.correlated_feature_sets_
# Out:
# []

# %%
len(smart_correlated.features_to_drop_)
# Out:
# 0

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
SBS_model = SelectByShuffling(estimator=linear_model, scoring="r2", cv=3)
SBS = SBS_model.fit_transform(X, y)

# %%
SBS_model.initial_model_performance_
# Out:
# 0.9535017407152283

# %%
SBS_model.performance_drifts_
# Out:
# {'Open': 18.59871028243525,
#  'Volume': -0.00013771852989263866,
#  'volume_cmf': -1.1557090207503506e-05,
#  'volume_fi': 0.0031581957958327633,
#  'volume_em': -0.00223075019175889,
#  'volume_sma_em': 0.001222132393274622,
#  'volume_vpt': 0.0006785548973260447,
#  'volume_mfi': -2.120505555203156e-05,
#  'volume_nvi': -1.5778415946021696e-05,
#  'volatility_bbw': 0.0002326753902142098,
#  'volatility_kcp': 0.008404548992833716,
#  'volatility_ui': -0.0003087962475754047,
#  'trend_macd': 0.00014999939133630846,
#  'trend_trix': -0.0058316829751727806,
#  'trend_mass_index': -1.958281242386839e-05,
#  'trend_dpo': 0.00029344907745210147,
#  'trend_kst': 0.0010696346584440075,
#  'trend_kst_diff': -0.00016856522055830325,
#  'trend_stc': 0.0006468149151748204,
#  'trend_adx': 0.0002467820674371124,
#  'trend_aroon_up': 9.984213806157882e-06,
#  'trend_aroon_down': -2.3744071333653416e-05,
#  'momentum_pvo': 4.5383098692730606e-05,
#  'momentum_pvo_hist': 0.00013807112734498528,
#  'others_dr': 0.0007245457262058386}

# %%
sorted_sbs_var = {var: val for var, val in sorted(SBS_model.performance_drifts_.items(), key=lambda item: item[1])}

# %%
sorted_sbs_var
# Out:
# {'trend_trix': -0.0058316829751727806,
#  'volume_em': -0.00223075019175889,
#  'volatility_ui': -0.0003087962475754047,
#  'trend_kst_diff': -0.00016856522055830325,
#  'Volume': -0.00013771852989263866,
#  'trend_aroon_down': -2.3744071333653416e-05,
#  'volume_mfi': -2.120505555203156e-05,
#  'trend_mass_index': -1.958281242386839e-05,
#  'volume_nvi': -1.5778415946021696e-05,
#  'volume_cmf': -1.1557090207503506e-05,
#  'trend_aroon_up': 9.984213806157882e-06,
#  'momentum_pvo': 4.5383098692730606e-05,
#  'momentum_pvo_hist': 0.00013807112734498528,
#  'trend_macd': 0.00014999939133630846,
#  'volatility_bbw': 0.0002326753902142098,
#  'trend_adx': 0.0002467820674371124,
#  'trend_dpo': 0.00029344907745210147,
#  'trend_stc': 0.0006468149151748204,
#  'volume_vpt': 0.0006785548973260447,
#  'others_dr': 0.0007245457262058386,
#  'trend_kst': 0.0010696346584440075,
#  'volume_sma_em': 0.001222132393274622,
#  'volume_fi': 0.0031581957958327633,
#  'volatility_kcp': 0.008404548992833716,
#  'Open': 18.59871028243525}

# %%
sfp = SelectBySingleFeaturePerformance(estimator=LinearRegression(), scoring="r2", cv=3, threshold=0.01)
sfp.fit(X, y)
# Out:
# SelectBySingleFeaturePerformance(estimator=LinearRegression(), scoring='r2',
#                                  threshold=0.01)

# %%
sorted_sfp_var = {var: val for var, val in sorted(sfp.feature_performance_.items(), key=lambda item: item[1])}
sorted_sfp_var
# Out:
# {'volume_nvi': -63.03826413349292,
#  'volume_cmf': -13.902931310049285,
#  'volatility_bbw': -12.670142786038056,
#  'volatility_ui': -12.589820019897013,
#  'trend_aroon_down': -12.272218177180294,
#  'volume_fi': -12.260251291335424,
#  'trend_aroon_up': -12.25304576946941,
#  'trend_mass_index': -12.052017592956085,
#  'trend_kst': -12.03063114458446,
#  'trend_trix': -12.008803423429383,
#  'volume_mfi': -11.983024140648725,
#  'volatility_kcp': -11.964910553413231,
#  'trend_adx': -11.846456377673356,
#  'trend_stc': -11.84070512191154,
#  'volume_sma_em': -11.838344418629353,
#  'volume_vpt': -11.818622927601057,
#  'momentum_pvo': -11.808529160348813,
#  'others_dr': -11.803090381435021,
#  'volume_em': -11.797661214552464,
#  'trend_dpo': -11.790188592522213,
#  'momentum_pvo_hist': -11.788628584453159,
#  'trend_kst_diff': -11.78517766496225,
#  'trend_macd': -11.723611566994856,
#  'Volume': -8.452838266038299,
#  'Open': 0.9862810864284722}

# %%
lr = LinearRegression()
lr_model = RecursiveFeatureElimination(estimator=lr, scoring="r2", cv=3)
lr_model.fit_transform(X, y)
lr_model.initial_model_performance_
# Out:
# 0.9535017407152283

# %%
lr_model.performance_drifts_
# Out:
# {'volume_fi': 0.011241836557854823,
#  'Volume': -0.0017267344649365413,
#  'volume_vpt': 0.017457678117178688,
#  'volume_nvi': -0.0037497772485611813,
#  'trend_dpo': -0.005596350387262028,
#  'trend_kst_diff': 0.007048728025979112,
#  'trend_aroon_down': 0.0008680342422869858,
#  'trend_kst': -0.00475548760159461,
#  'trend_macd': 0.0030356987385073975,
#  'trend_aroon_up': 0.0009696904316327526,
#  'trend_stc': -0.004275454034614712,
#  'volatility_bbw': -0.0015626539832537256,
#  'volume_mfi': -9.43088898863742e-07,
#  'momentum_pvo': 0.00012266512103309424,
#  'trend_adx': 0.0004304291222926304,
#  'volume_em': -0.002017514820376931,
#  'trend_mass_index': -0.0016822758532368809,
#  'volume_sma_em': 0.0004343070079950717,
#  'momentum_pvo_hist': 0.000705490534723241,
#  'volatility_ui': -0.0056853869454124295,
#  'Open': 19.099976714506685,
#  'volume_cmf': -0.0019780971317496787,
#  'trend_trix': 0.0019081715902937724,
#  'others_dr': -0.01390104813495241,
#  'volatility_kcp': -0.0008217509886936369}

# %%
sorted_lr_var = {var: val for var, val in sorted(lr_model.performance_drifts_.items(), key=lambda item: item[1])}
sorted_lr_var
# Out:
# {'others_dr': -0.01390104813495241,
#  'volatility_ui': -0.0056853869454124295,
#  'trend_dpo': -0.005596350387262028,
#  'trend_kst': -0.00475548760159461,
#  'trend_stc': -0.004275454034614712,
#  'volume_nvi': -0.0037497772485611813,
#  'volume_em': -0.002017514820376931,
#  'volume_cmf': -0.0019780971317496787,
#  'Volume': -0.0017267344649365413,
#  'trend_mass_index': -0.0016822758532368809,
#  'volatility_bbw': -0.0015626539832537256,
#  'volatility_kcp': -0.0008217509886936369,
#  'volume_mfi': -9.43088898863742e-07,
#  'momentum_pvo': 0.00012266512103309424,
#  'trend_adx': 0.0004304291222926304,
#  'volume_sma_em': 0.0004343070079950717,
#  'momentum_pvo_hist': 0.000705490534723241,
#  'trend_aroon_down': 0.0008680342422869858,
#  'trend_aroon_up': 0.0009696904316327526,
#  'trend_trix': 0.0019081715902937724,
#  'trend_macd': 0.0030356987385073975,
#  'trend_kst_diff': 0.007048728025979112,
#  'volume_fi': 0.011241836557854823,
#  'volume_vpt': 0.017457678117178688,
#  'Open': 19.099976714506685}

# %%
X.shape
# Out:
# (1786, 26)

# %%
X.drop(['trend_trix',
        'volume_em',
        'volume_nvi',
        'trend_kst_diff',
        'volatility_ui',
        'momentum_pvo',
        'Volume',
        'volume_cmf',
        'trend_mass_index',
        'volatility_bbw',
        'trend_dpo',
        'trend_stc',
        'others_dr',
        'volume_fi',
        'volatility_kcp',
        'trend_aroon_down'
        ], axis=1, inplace=True)

# %%
X.shape
# Out:
# (1786, 10)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1786 entries, 0 to 1785
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1786 non-null   datetime64[ns]
#  1   Open               1786 non-null   float64
#  2   volume_sma_em      1786 non-null   float64
#  3   volume_vpt         1786 non-null   float64
#  4   volume_mfi         1786 non-null   float64
#  5   trend_macd         1786 non-null   float64
#  6   trend_kst          1786 non-null   float64
#  7   trend_adx          1786 non-null   float64
#  8   trend_aroon_up     1786 non-null   float64
#  9   momentum_pvo_hist  1786 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 139.7 KB

# %%
eth_fe = X
eth_fe['Close'] = y
eth_fe = eth_fe.set_index('Date')
eth_fe.head()
# Out:
#                   Open  volume_sma_em    volume_vpt  volume_mfi  trend_macd  \
# Date
# 2017-11-09  308.644989       0.000000 -6.040389e+08   50.000000    0.000000
# 2017-11-10  320.670990     -29.372704 -6.972796e+08    0.000000   -1.725551
# 2017-11-11  298.585999     -15.705475 -1.630004e+07   49.109164   -1.827089
# 2017-11-12  314.690002     -10.465834  8.697287e+06   25.393798   -2.426118
# 2017-11-13  307.024994      -3.288123 -4.923305e+06   43.514011   -2.165161
#
#              trend_kst  trend_adx  trend_aroon_up  momentum_pvo_hist  \
# Date
# 2017-11-09 -713.747223        0.0             4.0           0.000000
# 2017-11-10 -723.395472        0.0             4.0          -0.051928
# 2017-11-11 -722.023905        0.0             4.0          -0.395627
# 2017-11-12 -722.848630        0.0             4.0           4.670449
# 2017-11-13 -721.771983        0.0             4.0           3.668302
#
#                  Close
# Date
# 2017-11-09  320.884003
# 2017-11-10  299.252991
# 2017-11-11  314.681000
# 2017-11-12  307.907990
# 2017-11-13  316.716003

# %%
vars_to_scale = ['volume_mfi',
                    'momentum_pvo_hist',
                    'trend_aroon_up',
                    'trend_macd',
                    'trend_adx',
                    'trend_kst',
                    'volume_sma_em',
                    'volume_vpt',
                    'Open',
                    'Close']

# %%
#train_len = 1700
train = eth_fe[0:train_len]
test = eth_fe[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 10)
# test :  (86, 10)

# %%
train
# Out:
#                    Open  volume_sma_em    volume_vpt  volume_mfi  trend_macd  \
# Date
# 2017-11-09   308.644989       0.000000 -6.040389e+08   50.000000    0.000000
# 2017-11-10   320.670990     -29.372704 -6.972796e+08    0.000000   -1.725551
# 2017-11-11   298.585999     -15.705475 -1.630004e+07   49.109164   -1.827089
# 2017-11-12   314.690002     -10.465834  8.697287e+06   25.393798   -2.426118
# 2017-11-13   307.024994      -3.288123 -4.923305e+06   43.514011   -2.165161
# ...                 ...            ...           ...         ...         ...
# 2022-07-01  1068.316772      -1.324219 -5.943204e+08   53.063979 -153.310052
# 2022-07-02  1060.121216       4.183951 -6.024581e+07   55.490956 -148.645771
# 2022-07-03  1066.467407       1.445122  1.214450e+08   52.705254 -142.718772
# 2022-07-04  1073.794312       1.075285  1.042265e+09   51.247409 -130.282935
# 2022-07-05  1150.509766       0.768135  7.516499e+08   51.346728 -120.372732
#
#              trend_kst  trend_adx  trend_aroon_up  momentum_pvo_hist  \
# Date
# 2017-11-09 -713.747223   0.000000             4.0           0.000000
# 2017-11-10 -723.395472   0.000000             4.0          -0.051928
# 2017-11-11 -722.023905   0.000000             4.0          -0.395627
# 2017-11-12 -722.848630   0.000000             4.0           4.670449
# 2017-11-13 -721.771983   0.000000             4.0           3.668302
# ...                ...        ...             ...                ...
# 2022-07-01 -310.215467  46.690077             4.0          -1.192426
# 2022-07-02 -293.976859  46.869906             4.0          -3.040641
# 2022-07-03 -274.793760  46.863303             4.0          -4.715567
# 2022-07-04 -259.054951  45.753644             4.0          -3.331595
# 2022-07-05 -246.361687  44.532380             4.0          -1.106749
#
#                   Close
# Date
# 2017-11-09   320.884003
# 2017-11-10   299.252991
# 2017-11-11   314.681000
# 2017-11-12   307.907990
# 2017-11-13   316.716003
# ...                 ...
# 2022-07-01  1059.767334
# 2022-07-02  1066.512817
# 2022-07-03  1073.766968
# 2022-07-04  1151.059082
# 2022-07-05  1134.541016
#
# [1700 rows x 10 columns]

# %%
train_sc = train.copy()
test_sc = test.copy()

# %%
scaler = QuantileTransformer(output_distribution='normal')
train_sc[vars_to_scale] = scaler.fit_transform(train[vars_to_scale])
test_sc[vars_to_scale] = scaler.transform(test[vars_to_scale])

# %%
train_sc.head()
# Out:
#                 Open  volume_sma_em  volume_vpt  volume_mfi  trend_macd  \
# Date
# 2017-11-09 -0.212904       0.056381   -1.066899   -0.101723   -0.044498
# 2017-11-10 -0.190632      -1.189463   -1.167103   -5.199338   -0.104262
# 2017-11-11 -0.223897      -0.898856   -0.125097   -0.144884   -0.108509
# 2017-11-12 -0.202806      -0.771475   -0.011286   -1.697130   -0.125480
# 2017-11-13 -0.216266      -0.590979   -0.067160   -0.442404   -0.117910
#
#             trend_kst  trend_adx  trend_aroon_up  momentum_pvo_hist     Close
# Date
# 2017-11-09  -2.646102  -5.199338       -5.199338           0.108863 -0.191488
# 2017-11-10  -5.199338  -5.199338       -5.199338           0.096312 -0.223889
# 2017-11-11  -3.055771  -5.199338       -5.199338          -0.021634 -0.204081
# 2017-11-12  -3.298112  -5.199338       -5.199338           1.290358 -0.215981
# 2017-11-13  -3.024232  -5.199338       -5.199338           1.080148 -0.200745

# %%
trainX = []
trainY = []
testX = []
testY = []

# %%
n_future = 1
n_past = 2

for i in range (n_past, len(train_sc) - n_future +1):
    trainX.append(train_sc[i - n_past : i])
    trainY.append(train_sc[i + n_future - 1 : i + n_future].Close)
for i in range (n_past, len(test_sc) - n_future +1):
    testX.append(test_sc[i - n_past : i])
    testY.append(test_sc[i + n_future - 1 : i + n_future].Close)

# %%
train_sc.head()
# Out:
#                 Open  volume_sma_em  volume_vpt  volume_mfi  trend_macd  \
# Date
# 2017-11-09 -0.212904       0.056381   -1.066899   -0.101723   -0.044498
# 2017-11-10 -0.190632      -1.189463   -1.167103   -5.199338   -0.104262
# 2017-11-11 -0.223897      -0.898856   -0.125097   -0.144884   -0.108509
# 2017-11-12 -0.202806      -0.771475   -0.011286   -1.697130   -0.125480
# 2017-11-13 -0.216266      -0.590979   -0.067160   -0.442404   -0.117910
#
#             trend_kst  trend_adx  trend_aroon_up  momentum_pvo_hist     Close
# Date
# 2017-11-09  -2.646102  -5.199338       -5.199338           0.108863 -0.191488
# 2017-11-10  -5.199338  -5.199338       -5.199338           0.096312 -0.223889
# 2017-11-11  -3.055771  -5.199338       -5.199338          -0.021634 -0.204081
# 2017-11-12  -3.298112  -5.199338       -5.199338           1.290358 -0.215981
# 2017-11-13  -3.024232  -5.199338       -5.199338           1.080148 -0.200745

# %%
trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)
print (trainX.shape)
print (trainY.shape)
print (testX.shape)
print (testY.shape)
# Out:
# (1698, 2, 10)
# (1698, 1)
# (84, 2, 10)
# (84, 1)

# %%
model = Sequential()
model.add(LSTM(64, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(32, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(16, activation = 'relu', return_sequences=False))
#model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 2, 64)             19200
#
#  lstm_10 (LSTM)              (None, 2, 32)             12416
#
#  lstm_11 (LSTM)              (None, 16)                3136
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 34,769
# Trainable params: 34,769
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

checkpoint = ModelCheckpoint(filepath='best_model.hdf5',
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]

history = model.fit(trainX, trainY, 
                    epochs=500, 
#                    batch_size=32, 
                    batch_size=24,
                    verbose='auto', 
                    shuffle=False, 
                    validation_data=(testX, testY),
                    callbacks=callbacks)
# Out:
# Epoch 1/500
# 55/71 [======================>.......] - ETA: 0s - loss: 0.7788
# Epoch 1: val_loss improved from inf to 0.31479, saving model to best_model.hdf5
# 71/71 [==============================] - 3s 12ms/step - loss: 1.0366 - val_loss: 0.3148
# Epoch 2/500
# 70/71 [============================>.] - ETA: 0s - loss: 0.9149
# Epoch 2: val_loss improved from 0.31479 to 0.13802, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.9068 - val_loss: 0.1380
# Epoch 3/500
# 57/71 [=======================>......] - ETA: 0s - loss: 0.4996
# Epoch 3: val_loss improved from 0.13802 to 0.06217, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.4971 - val_loss: 0.0622
# Epoch 4/500
# 65/71 [==========================>...] - ETA: 0s - loss: 0.2518
# Epoch 4: val_loss improved from 0.06217 to 0.03009, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2361 - val_loss: 0.0301
# Epoch 5/500
# 59/71 [=======================>......] - ETA: 0s - loss: 0.0741
# Epoch 5: val_loss improved from 0.03009 to 0.01299, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0837 - val_loss: 0.0130
# Epoch 6/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0497
# Epoch 6: val_loss did not improve from 0.01299
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0491 - val_loss: 0.0205
# Epoch 7/500
# 57/71 [=======================>......] - ETA: 0s - loss: 0.0258
# Epoch 7: val_loss did not improve from 0.01299
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0394 - val_loss: 0.0288
# Epoch 8/500
# 58/71 [=======================>......] - ETA: 0s - loss: 0.0309
# Epoch 8: val_loss improved from 0.01299 to 0.00767, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0373 - val_loss: 0.0077
# Epoch 9/500
# 64/71 [==========================>...] - ETA: 0s - loss: 0.0315
# Epoch 9: val_loss improved from 0.00767 to 0.00705, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0298 - val_loss: 0.0070
# Epoch 10/500
# 62/71 [=========================>....] - ETA: 0s - loss: 0.0293
# Epoch 10: val_loss improved from 0.00705 to 0.00597, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0274 - val_loss: 0.0060
# Epoch 11/500
# 69/71 [============================>.] - ETA: 0s - loss: 0.0255
# Epoch 11: val_loss improved from 0.00597 to 0.00410, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0250 - val_loss: 0.0041
# Epoch 12/500
# 66/71 [==========================>...] - ETA: 0s - loss: 0.0250
# Epoch 12: val_loss improved from 0.00410 to 0.00373, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0238 - val_loss: 0.0037
# Epoch 13/500
# 65/71 [==========================>...] - ETA: 0s - loss: 0.0256
# Epoch 13: val_loss improved from 0.00373 to 0.00323, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0241 - val_loss: 0.0032
# Epoch 14/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0244
# Epoch 14: val_loss improved from 0.00323 to 0.00290, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0029
# Epoch 15/500
# 66/71 [==========================>...] - ETA: 0s - loss: 0.0239
# Epoch 15: val_loss improved from 0.00290 to 0.00267, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 6ms/step - loss: 0.0226 - val_loss: 0.0027
# Epoch 16/500
# 58/71 [=======================>......] - ETA: 0s - loss: 0.0181
# Epoch 16: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0230 - val_loss: 0.0031
# Epoch 17/500
# 64/71 [==========================>...] - ETA: 0s - loss: 0.0240
# Epoch 17: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0226 - val_loss: 0.0032
# Epoch 18/500
# 63/71 [=========================>....] - ETA: 0s - loss: 0.0244
# Epoch 18: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0230 - val_loss: 0.0033
# Epoch 19/500
# 58/71 [=======================>......] - ETA: 0s - loss: 0.0189
# Epoch 19: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0228 - val_loss: 0.0036
# Epoch 20/500
# 69/71 [============================>.] - ETA: 0s - loss: 0.0234
# Epoch 20: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0229 - val_loss: 0.0040
# Epoch 21/500
# 70/71 [============================>.] - ETA: 0s - loss: 0.0239
# Epoch 21: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0236 - val_loss: 0.0044
# Epoch 22/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0238
# Epoch 22: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0230 - val_loss: 0.0049
# Epoch 23/500
# 56/71 [======================>.......] - ETA: 0s - loss: 0.0192
# Epoch 23: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0228 - val_loss: 0.0046
# Epoch 24/500
# 67/71 [===========================>..] - ETA: 0s - loss: 0.0231
# Epoch 24: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0223 - val_loss: 0.0060
# Epoch 25/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0230
# Epoch 25: val_loss did not improve from 0.00267
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0222 - val_loss: 0.0055

# %%
result_sc = model.predict(testX)
result_sc.shape
# Out:
# 3/3 [==============================] - 0s 0s/step
# (84, 1)

# %%
result_sc = np.repeat(result_sc, 10, axis=-1)
result_sc.shape
# Out:
# (84, 10)

# %%
result = scaler.inverse_transform(result_sc)

# %%
pred_dates = test.index[:-n_past]
pred_dates.shape
# Out:
# (84,)

# %%
result_df = pd.DataFrame(result)
pred_df = pd.DataFrame(result, columns = ['Open',
            'volume_sma_em',
            'volume_vpt',
            'volume_mfi',
            'trend_macd',
            'trend_kst',
            'trend_adx',
            'trend_aroon_up',
            'momentum_pvo_hist',
            'Close'])
pred_df.index = pred_dates
pred_df.head()
# Out:
#                  Open  volume_sma_em  volume_vpt  volume_mfi  trend_macd  \
# Date
# 2022-07-06  61.849449       1.218060   79.199059   11.560678   35.035343
# 2022-07-07  60.681690       1.061419   76.000000   10.148555   33.966652
# 2022-07-08  59.642811       0.937725   75.869156    8.816915   33.405731
# 2022-07-09  59.635040       0.937286   74.345985    8.775507   33.350822
# 2022-07-10  59.864174       0.962891   76.000000    9.105197   33.509480
#
#              trend_kst  trend_adx  trend_aroon_up  momentum_pvo_hist  \
# Date
# 2022-07-06  144.020340   0.375541     238678240.0        1211.599854
# 2022-07-07  132.330063   0.316980     202179136.0        1070.403320
# 2022-07-08  117.441872   0.260907     177480080.0         945.383301
# 2022-07-09  116.621811   0.254514     176814720.0         940.719788
# 2022-07-10  119.115448   0.272911     187469280.0         979.764465
#
#                   Close
# Date
# 2022-07-06  1211.499634
# 2022-07-07  1074.290039
# 2022-07-08   961.837402
# 2022-07-09   950.639343
# 2022-07-10   988.144714

# %%
plt.figure(figsize=(12,4))
plt.plot( train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(pred_df['Close'], label='LSTM')
plt.legend(loc='best')
plt.title('LSTM')
plt.show()

# %%
mse = mean_squared_error(test['Close'][:-n_past], pred_df['Close']).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'][:-n_past], pred_df['Close']).round(2)
mape = np.round(np.mean(np.abs(test['Close'][:-n_past] - pred_df['Close'])/test['Close'][:-n_past])*100,2)

# %%
model_param.loc[15] = ['LSTM - ETH FE Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
# 14                           LSTM - BTC FE variables   18038.48  134.31
# 15                           LSTM - ETH FE Variables   30923.60  175.85
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52
# 13       0.18   8.75
# 14       0.60   7.69
# 15       0.31   9.44

# %%
a = pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-LSTM - ETH FE Variables.xlsx')

# %%
c = a
c = pd.DataFrame(c)
c.columns = ['LSTM - ETH FE Variables']
b = b.join(c)

# %% [markdown]
# #### Grid Search with ETH FE variables

# %%
train = eth_fe[0:train_len]
test = eth_fe[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 10)
# test :  (86, 10)

# %%
y_train = train['Close']
X_train = train.drop(['Close'], axis=1)
y_test = test['Close']
X_test = test.drop(['Close'], axis=1)

# %%
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1700,)
# (1700, 9)
# (86,)
# (86, 9)

# %%
# Parameter tuining using GridSearch CV
params = {
    'max_depth': [6, 8, 10],
    'n_estimators': [20, 30, 40],
    'max_features': [8, 9],
    'min_samples_split': [5, 6],
    'bootstrap': [True], 
    'oob_score': [True], 
    'n_jobs': [-1],
    'min_samples_leaf':  [8, 9, 10],
    'max_leaf_nodes': [175],
    'random_state':[41, 90, 100]
}

# %%
rf_model = RandomForestRegressor()
y_scorer = make_scorer('neg_mean_absolute_percentage_error', greater_is_better=False)
grid_search_rf = GridSearchCV(estimator=rf_model,
                                    param_grid=params,
                                    cv=2, n_jobs=-1, verbose=1, scoring = 'neg_mean_absolute_percentage_error')
grid_search_rf.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 324 candidates, totalling 648 fits
# GridSearchCV(cv=2, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [6, 8, 10],
#                          'max_features': [8, 9], 'max_leaf_nodes': [175],
#                          'min_samples_leaf': [8, 9, 10],
#                          'min_samples_split': [5, 6],
#                          'n_estimators': [20, 30, 40], 'n_jobs': [-1],
#                          'oob_score': [True], 'random_state': [41, 90, 100]},
#              scoring='neg_mean_absolute_percentage_error', verbose=1)

# %%
score_df = pd.DataFrame(grid_search_rf.cv_results_)
score_df.sort_values(['rank_test_score'], inplace=True)

# %%
dt_best = grid_search_rf.best_estimator_
dt_best
# Out:
# RandomForestRegressor(max_depth=6, max_features=9, max_leaf_nodes=175,
#                       min_samples_leaf=9, min_samples_split=5, n_estimators=20,
#                       n_jobs=-1, oob_score=True, random_state=90)

# %%
rf_model = dt_best
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=6, max_features=9, max_leaf_nodes=175,
#                       min_samples_leaf=9, min_samples_split=5, n_estimators=20,
#                       n_jobs=-1, oob_score=True, random_state=90)

# %%
y_pred = rf_model.predict(X_test)

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df['Date'] = y_test.index
y_pred_df = y_pred_df.set_index('Date')
y_pred_df['Close'] = y_pred_df[0]
y_pred_df.drop([0], axis=1, inplace=True)

# %%
a = test.copy()
a['pred-close'] = y_pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-RF Grid Search - ETH FE Variables.xlsx')

# %%
c = a['pred-close']
c = pd.DataFrame(c)
c.columns = ['RF Grid Search - ETH FE Variables']
b = b.join(c)

# %%
plt.figure(figsize=(12,4))
plt.plot( train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(y_pred_df['Close'], label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred_df).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_test, y_pred_df).round(2)
mape = np.round(np.mean(np.abs(y_test - y_pred_df['Close'])/y_test)*100,2)

# %%
model_param.loc[16] = ['RF Grid Search - ETH FE Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
# 14                           LSTM - BTC FE variables   18038.48  134.31
# 15                           LSTM - ETH FE Variables   30923.60  175.85
# 16                 RF Grid Search - ETH FE Variables    6236.38   78.97
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52
# 13       0.18   8.75
# 14       0.60   7.69
# 15       0.31   9.44
# 16       0.86   3.75

# %% [markdown]
# #### Grid Search with XMR FE variables & 1 lag

# %%
eth_lag = eth_fe.copy()

# %%
eth_lag['Close_lag_1'] = eth_lag['Close'].shift(1)
eth_lag.dropna(inplace=True)
eth_lag.head()
# Out:
#                   Open  volume_sma_em    volume_vpt  volume_mfi  trend_macd  \
# Date
# 2017-11-10  320.670990     -29.372704 -6.972796e+08    0.000000   -1.725551
# 2017-11-11  298.585999     -15.705475 -1.630004e+07   49.109164   -1.827089
# 2017-11-12  314.690002     -10.465834  8.697287e+06   25.393798   -2.426118
# 2017-11-13  307.024994      -3.288123 -4.923305e+06   43.514011   -2.165161
# 2017-11-14  316.763000       2.075592  1.004429e+08   55.186360   -0.267599
#
#              trend_kst  trend_adx  trend_aroon_up  momentum_pvo_hist  \
# Date
# 2017-11-10 -723.395472        0.0             4.0          -0.051928
# 2017-11-11 -722.023905        0.0             4.0          -0.395627
# 2017-11-12 -722.848630        0.0             4.0           4.670449
# 2017-11-13 -721.771983        0.0             4.0           3.668302
# 2017-11-14 -717.944590        0.0            24.0           3.001610
#
#                  Close  Close_lag_1
# Date
# 2017-11-10  299.252991   320.884003
# 2017-11-11  314.681000   299.252991
# 2017-11-12  307.907990   314.681000
# 2017-11-13  316.716003   307.907990
# 2017-11-14  337.631012   316.716003

# %%
train = eth_lag[0:train_len]
test = eth_lag[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 11)
# test :  (85, 11)

# %%
y_train = train['Close']
X_train = train.drop(['Close'], axis=1)
y_test = test['Close']
X_test = test.drop(['Close'], axis=1)

# %%
print(y_train.shape)
print(X_train.shape)
print(y_test.shape)
print(X_test.shape)
# Out:
# (1700,)
# (1700, 10)
# (85,)
# (85, 10)

# %%
# Parameter tuining using GridSearch CV
params = {
    'max_depth': [10, 12],
    'n_estimators': [18, 20, 22],
    'max_features': [8, 9],
    'min_samples_split': [3, 4],
    'bootstrap': [True], 
    'oob_score': [True], 
    'n_jobs': [-1],
    'min_samples_leaf':  [3, 4],
    'max_leaf_nodes': [150],
    'random_state':[21, 41]
}

# %%
rf_model = RandomForestRegressor()
y_scorer = make_scorer('neg_mean_absolute_percentage_error', greater_is_better=False)
grid_search_rf = GridSearchCV(estimator=rf_model,
                                    param_grid=params,
                                    cv=2, n_jobs=-1, verbose=1, scoring = 'neg_mean_absolute_percentage_error')
grid_search_rf.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 96 candidates, totalling 192 fits
# GridSearchCV(cv=2, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [10, 12],
#                          'max_features': [8, 9], 'max_leaf_nodes': [150],
#                          'min_samples_leaf': [3, 4],
#                          'min_samples_split': [3, 4],
#                          'n_estimators': [18, 20, 22], 'n_jobs': [-1],
#                          'oob_score': [True], 'random_state': [21, 41]},
#              scoring='neg_mean_absolute_percentage_error', verbose=1)

# %%
score_df = pd.DataFrame(grid_search_rf.cv_results_)
score_df.sort_values(['rank_test_score'], inplace=True)

# %%
dt_best = grid_search_rf.best_estimator_
dt_best
# Out:
# RandomForestRegressor(max_depth=12, max_features=9, max_leaf_nodes=150,
#                       min_samples_leaf=3, min_samples_split=3, n_estimators=22,
#                       n_jobs=-1, oob_score=True, random_state=41)

# %%
rf_model = dt_best
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=12, max_features=9, max_leaf_nodes=150,
#                       min_samples_leaf=3, min_samples_split=3, n_estimators=22,
#                       n_jobs=-1, oob_score=True, random_state=41)

# %%
y_pred = rf_model.predict(X_test)

# %%
y_pred_df = pd.DataFrame(y_pred)
y_pred_df['Date'] = y_test.index
y_pred_df = y_pred_df.set_index('Date')
y_pred_df['Close'] = y_pred_df[0]
y_pred_df.drop([0], axis=1, inplace=True)

# %%
a = test.copy()
a['pred-close'] = y_pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-RF Grid Search - 1 lag with ETH FE Variables.xlsx')

# %%
c = a['pred-close']
c = pd.DataFrame(c)
c.columns = ['RF Grid Search - 1 lag with ETH FE Variables']
b = b.join(c)

# %%
plt.figure(figsize=(12,4))
plt.plot( train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(y_pred_df['Close'], label='Random Forest')
plt.legend(loc='best')
plt.title('Random Forest')
plt.show()

# %%
mse = mean_squared_error(y_test, y_pred_df).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(y_test, y_pred_df).round(2)
mape = np.round(np.mean(np.abs(y_test - y_pred_df['Close'])/y_test)*100,2)

# %%
model_param.loc[17] = ['RF Grid Search - 1 lag with ETH FE Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
# 14                           LSTM - BTC FE variables   18038.48  134.31
# 15                           LSTM - ETH FE Variables   30923.60  175.85
# 16                 RF Grid Search - ETH FE Variables    6236.38   78.97
# 17      RF Grid Search - 1 lag with ETH FE Variables    5281.23   72.67
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52
# 13       0.18   8.75
# 14       0.60   7.69
# 15       0.31   9.44
# 16       0.86   3.75
# 17       0.88   3.52

# %% [markdown]
# #### LSTM with base ETH variables

# %%
eth_lstm = eth.copy()

# %%
eth_lstm = eth_lstm.set_index('Date')
eth_lstm.head()
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003   893249984
# 2017-11-10  320.670990  324.717987  294.541992  299.252991   885985984
# 2017-11-11  298.585999  319.453003  298.191986  314.681000   842300992
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  1613479936
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  1041889984

# %%
vars_to_scale = ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
#train_len = 1700
train = eth_lstm[0:train_len]
test = eth_lstm[train_len:]
print('train : ', train.shape )
print('test : ', test.shape )
# Out:
# train :  (1700, 5)
# test :  (86, 5)

# %%
train_sc = train.copy()
test_sc = test.copy()

# %%
scaler = QuantileTransformer(output_distribution='normal')
train_sc[vars_to_scale] = scaler.fit_transform(train[vars_to_scale])
test_sc[vars_to_scale] = scaler.transform(test[vars_to_scale])

# %%
train_sc.head()
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2017-11-09 -0.212904 -0.194041 -0.198258 -0.191488 -2.620560
# 2017-11-10 -0.190632 -0.200389 -0.213872 -0.223889 -2.634503
# 2017-11-11 -0.223897 -0.209125 -0.209095 -0.204081 -2.698941
# 2017-11-12 -0.202806 -0.210099 -0.208732 -0.215981 -1.397886
# 2017-11-13 -0.216266 -0.195818 -0.198344 -0.200745 -2.346152

# %%
trainX = []
trainY = []
testX = []
testY = []

# %%
n_future = 1
n_past = 2

for i in range (n_past, len(train_sc) - n_future +1):
    trainX.append(train_sc[i - n_past : i])
    trainY.append(train_sc[i + n_future - 1 : i + n_future].Close)
for i in range (n_past, len(test_sc) - n_future +1):
    testX.append(test_sc[i - n_past : i])
    testY.append(test_sc[i + n_future - 1 : i + n_future].Close)

# %%
train_sc.head()
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2017-11-09 -0.212904 -0.194041 -0.198258 -0.191488 -2.620560
# 2017-11-10 -0.190632 -0.200389 -0.213872 -0.223889 -2.634503
# 2017-11-11 -0.223897 -0.209125 -0.209095 -0.204081 -2.698941
# 2017-11-12 -0.202806 -0.210099 -0.208732 -0.215981 -1.397886
# 2017-11-13 -0.216266 -0.195818 -0.198344 -0.200745 -2.346152

# %%
trainX, trainY = np.array(trainX), np.array(trainY)
testX, testY = np.array(testX), np.array(testY)
print (trainX.shape)
print (trainY.shape)
print (testX.shape)
print (testY.shape)
# Out:
# (1698, 2, 5)
# (1698, 1)
# (84, 2, 5)
# (84, 1)

# %%
model = Sequential()
model.add(LSTM(64, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(32, activation = 'relu', input_shape = (trainX.shape[1], trainX.shape[2]),return_sequences=True))
model.add(LSTM(16, activation = 'relu', return_sequences=False))
#model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 2, 64)             17920
#
#  lstm_13 (LSTM)              (None, 2, 32)             12416
#
#  lstm_14 (LSTM)              (None, 16)                3136
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 33,489
# Trainable params: 33,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

checkpoint = ModelCheckpoint(filepath='best_model.hdf5',
                             monitor='val_loss', 
                             verbose=1, 
                             save_best_only=True, 
                             mode='min')

earlystopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

callbacks = [checkpoint, earlystopping]

history = model.fit(trainX, trainY, 
                    epochs=500, 
#                    batch_size=32, 
                    batch_size=24,
                    verbose='auto', 
                    shuffle=False, 
                    validation_data=(testX, testY),
                    callbacks=callbacks)
# Out:
# Epoch 1/500
# 53/71 [=====================>........] - ETA: 0s - loss: 0.7327
# Epoch 1: val_loss improved from inf to 0.28389, saving model to best_model.hdf5
# 71/71 [==============================] - 3s 9ms/step - loss: 1.0064 - val_loss: 0.2839
# Epoch 2/500
# 62/71 [=========================>....] - ETA: 0s - loss: 0.6257
# Epoch 2: val_loss improved from 0.28389 to 0.15925, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.6002 - val_loss: 0.1593
# Epoch 3/500
# 62/71 [=========================>....] - ETA: 0s - loss: 3.5540
# Epoch 3: val_loss improved from 0.15925 to 0.07186, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 3.1680 - val_loss: 0.0719
# Epoch 4/500
# 57/71 [=======================>......] - ETA: 0s - loss: 0.2632
# Epoch 4: val_loss did not improve from 0.07186
# 71/71 [==============================] - 0s 4ms/step - loss: 0.3170 - val_loss: 0.0765
# Epoch 5/500
# 67/71 [===========================>..] - ETA: 0s - loss: 0.2921
# Epoch 5: val_loss improved from 0.07186 to 0.01927, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2815 - val_loss: 0.0193
# Epoch 6/500
# 60/71 [========================>.....] - ETA: 0s - loss: 0.1781
# Epoch 6: val_loss did not improve from 0.01927
# 71/71 [==============================] - 0s 5ms/step - loss: 0.2019 - val_loss: 0.0318
# Epoch 7/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.1674
# Epoch 7: val_loss improved from 0.01927 to 0.00132, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 6ms/step - loss: 0.1613 - val_loss: 0.0013
# Epoch 8/500
# 69/71 [============================>.] - ETA: 0s - loss: 0.1228
# Epoch 8: val_loss did not improve from 0.00132
# 71/71 [==============================] - 0s 5ms/step - loss: 0.1207 - val_loss: 0.0302
# Epoch 9/500
# 66/71 [==========================>...] - ETA: 0s - loss: 0.0742
# Epoch 9: val_loss did not improve from 0.00132
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0702 - val_loss: 0.0085
# Epoch 10/500
# 63/71 [=========================>....] - ETA: 0s - loss: 0.0472
# Epoch 10: val_loss did not improve from 0.00132
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0455 - val_loss: 0.0028
# Epoch 11/500
# 61/71 [========================>.....] - ETA: 0s - loss: 0.0490
# Epoch 11: val_loss did not improve from 0.00132
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0465 - val_loss: 0.0071
# Epoch 12/500
# 69/71 [============================>.] - ETA: 0s - loss: 0.0411
# Epoch 12: val_loss improved from 0.00132 to 0.00088, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 8.8015e-04
# Epoch 13/500
# 69/71 [============================>.] - ETA: 0s - loss: 0.0359
# Epoch 13: val_loss did not improve from 0.00088
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0351 - val_loss: 0.0028
# Epoch 14/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0321
# Epoch 14: val_loss did not improve from 0.00088
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0059
# Epoch 15/500
# 64/71 [==========================>...] - ETA: 0s - loss: 0.0329
# Epoch 15: val_loss did not improve from 0.00088
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0306 - val_loss: 0.0051
# Epoch 16/500
# 63/71 [=========================>....] - ETA: 0s - loss: 0.0317
# Epoch 16: val_loss did not improve from 0.00088
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0291 - val_loss: 0.0014
# Epoch 17/500
# 65/71 [==========================>...] - ETA: 0s - loss: 0.0283
# Epoch 17: val_loss improved from 0.00088 to 0.00068, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0264 - val_loss: 6.7701e-04
# Epoch 18/500
# 55/71 [======================>.......] - ETA: 0s - loss: 0.0209
# Epoch 18: val_loss did not improve from 0.00068
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0254 - val_loss: 0.0014
# Epoch 19/500
# 71/71 [==============================] - ETA: 0s - loss: 0.0251
# Epoch 19: val_loss did not improve from 0.00068
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0251 - val_loss: 0.0033
# Epoch 20/500
# 68/71 [===========================>..] - ETA: 0s - loss: 0.0258
# Epoch 20: val_loss did not improve from 0.00068
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0254 - val_loss: 0.0064
# Epoch 21/500
# 62/71 [=========================>....] - ETA: 0s - loss: 0.0253
# Epoch 21: val_loss did not improve from 0.00068
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0237 - val_loss: 0.0025
# Epoch 22/500
# 61/71 [========================>.....] - ETA: 0s - loss: 0.0235
# Epoch 22: val_loss improved from 0.00068 to 0.00064, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0227 - val_loss: 6.3566e-04
# Epoch 23/500
# 53/71 [=====================>........] - ETA: 0s - loss: 0.0165
# Epoch 23: val_loss did not improve from 0.00064
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0216 - val_loss: 6.7195e-04
# Epoch 24/500
# 55/71 [======================>.......] - ETA: 0s - loss: 0.0165
# Epoch 24: val_loss improved from 0.00064 to 0.00059, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0215 - val_loss: 5.8516e-04
# Epoch 25/500
# 54/71 [=====================>........] - ETA: 0s - loss: 0.0165
# Epoch 25: val_loss did not improve from 0.00059
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0214 - val_loss: 0.0012
# Epoch 26/500
# 65/71 [==========================>...] - ETA: 0s - loss: 0.0234
# Epoch 26: val_loss did not improve from 0.00059
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0226 - val_loss: 0.0042
# Epoch 27/500
# 65/71 [==========================>...] - ETA: 0s - loss: 0.0234
# Epoch 27: val_loss did not improve from 0.00059
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0227 - val_loss: 0.0058
# Epoch 28/500
# 70/71 [============================>.] - ETA: 0s - loss: 0.0227
# Epoch 28: val_loss did not improve from 0.00059
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0225 - val_loss: 0.0026
# Epoch 29/500
# 56/71 [======================>.......] - ETA: 0s - loss: 0.0152
# Epoch 29: val_loss did not improve from 0.00059
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0208 - val_loss: 6.4289e-04
# Epoch 30/500
# 54/71 [=====================>........] - ETA: 0s - loss: 0.0163
# Epoch 30: val_loss did not improve from 0.00059
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0211 - val_loss: 6.3391e-04
# Epoch 31/500
# 56/71 [======================>.......] - ETA: 0s - loss: 0.0148
# Epoch 31: val_loss improved from 0.00059 to 0.00058, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0202 - val_loss: 5.7775e-04
# Epoch 32/500
# 64/71 [==========================>...] - ETA: 0s - loss: 0.0225
# Epoch 32: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0210 - val_loss: 0.0013
# Epoch 33/500
# 65/71 [==========================>...] - ETA: 0s - loss: 0.0229
# Epoch 33: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0221 - val_loss: 0.0043
# Epoch 34/500
# 58/71 [=======================>......] - ETA: 0s - loss: 0.0179
# Epoch 34: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0254 - val_loss: 0.0075
# Epoch 35/500
# 59/71 [=======================>......] - ETA: 0s - loss: 0.0150
# Epoch 35: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0217 - val_loss: 0.0038
# Epoch 36/500
# 55/71 [======================>.......] - ETA: 0s - loss: 0.0166
# Epoch 36: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0012
# Epoch 37/500
# 71/71 [==============================] - ETA: 0s - loss: 0.0197
# Epoch 37: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0197 - val_loss: 6.2382e-04
# Epoch 38/500
# 63/71 [=========================>....] - ETA: 0s - loss: 0.0217
# Epoch 38: val_loss improved from 0.00058 to 0.00058, saving model to best_model.hdf5
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 5.7507e-04
# Epoch 39/500
# 57/71 [=======================>......] - ETA: 0s - loss: 0.0140
# Epoch 39: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0203 - val_loss: 9.2366e-04
# Epoch 40/500
# 70/71 [============================>.] - ETA: 0s - loss: 0.0209
# Epoch 40: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0208 - val_loss: 0.0025
# Epoch 41/500
# 55/71 [======================>.......] - ETA: 0s - loss: 0.0150
# Epoch 41: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0223 - val_loss: 0.0040
# Epoch 42/500
# 62/71 [=========================>....] - ETA: 0s - loss: 0.0231
# Epoch 42: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0225 - val_loss: 0.0055
# Epoch 43/500
# 56/71 [======================>.......] - ETA: 0s - loss: 0.0146
# Epoch 43: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0217 - val_loss: 0.0043
# Epoch 44/500
# 60/71 [========================>.....] - ETA: 0s - loss: 0.0150
# Epoch 44: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0213 - val_loss: 0.0030
# Epoch 45/500
# 60/71 [========================>.....] - ETA: 0s - loss: 0.0144
# Epoch 45: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0206 - val_loss: 0.0020
# Epoch 46/500
# 61/71 [========================>.....] - ETA: 0s - loss: 0.0198
# Epoch 46: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0200 - val_loss: 0.0016
# Epoch 47/500
# 60/71 [========================>.....] - ETA: 0s - loss: 0.0140
# Epoch 47: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 4ms/step - loss: 0.0201 - val_loss: 0.0018
# Epoch 48/500
# 70/71 [============================>.] - ETA: 0s - loss: 0.0204
# Epoch 48: val_loss did not improve from 0.00058
# 71/71 [==============================] - 0s 5ms/step - loss: 0.0202 - val_loss: 0.0021

# %%
result_sc = model.predict(testX)
result_sc.shape
# Out:
# 3/3 [==============================] - 1s 0s/step
# (84, 1)

# %%
result_sc = np.repeat(result_sc, 5, axis=-1)
result_sc.shape
# Out:
# (84, 5)

# %%
result = scaler.inverse_transform(result_sc)

# %%
pred_dates = test.index[:-n_past]
pred_dates.shape
# Out:
# (84,)

# %%
result_df = pd.DataFrame(result)
pred_df = pd.DataFrame(result, columns = ['Open', 'High', 'Low', 'Close', 'Volume'])
pred_df.index = pred_dates
pred_df.head()
# Out:
#                    Open         High          Low        Close        Volume
# Date
# 2022-07-06  1197.416748  1254.796265  1099.065308  1197.658325  1.602319e+10
# 2022-07-07  1228.808350  1272.039551  1152.119385  1228.667603  1.614082e+10
# 2022-07-08  1168.304321  1247.522095  1091.613159  1166.109131  1.599629e+10
# 2022-07-09  1147.687256  1233.786011  1064.303711  1148.786133  1.592648e+10
# 2022-07-10  1130.176392  1182.919189  1054.615356  1132.787842  1.586527e+10

# %%
plt.figure(figsize=(12,4))
plt.plot( train['Close'], label='Train')
plt.plot(test['Close'], label='Test')
plt.plot(pred_df['Close'], label='LSTM')
plt.legend(loc='best')
plt.title('LSTM')
plt.show()

# %%
mse = mean_squared_error(test['Close'][:-n_past], pred_df['Close']).round(2)
rmse = np.sqrt(mse).round(2)
r2 = r2_score(test['Close'][:-n_past], pred_df['Close']).round(2)
mape = np.round(np.mean(np.abs(test['Close'][:-n_past] - pred_df['Close'])/test['Close'][:-n_past])*100,2)

# %%
model_param.loc[18] = ['LSTM - ETH base Variables', mse, rmse, r2, mape]
model_param
# Out:
#                                                model        MSE    RMSE  \
# 0                                               ARMA  177127.00  420.86
# 1                                              ARIMA  177127.00  420.86
# 2                                             SARIMA  154234.99  392.73
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
# 14                           LSTM - BTC FE variables   18038.48  134.31
# 15                           LSTM - ETH FE Variables   30923.60  175.85
# 16                 RF Grid Search - ETH FE Variables    6236.38   78.97
# 17      RF Grid Search - 1 lag with ETH FE Variables    5281.23   72.67
# 18                         LSTM - ETH base Variables    3737.33   61.13
#
#     R-Squared   MAPE
# 0       -2.93  22.48
# 1       -2.93  22.48
# 2       -2.42  20.37
# 3       -4.48  28.44
# 4       -5.87  31.86
# 5        0.75   5.32
# 6        0.70   5.28
# 7       -6.25  29.61
# 8       -8.29  34.85
# 9        0.96   2.15
# 10       0.94   2.31
# 11       0.96   2.11
# 12       0.87   3.52
# 13       0.18   8.75
# 14       0.60   7.69
# 15       0.31   9.44
# 16       0.86   3.75
# 17       0.88   3.52
# 18       0.92   3.03

# %%
a = pred_df['Close']
a.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-LSTM - ETH base Variables.xlsx')

# %%
c = pd.DataFrame(a)
c.columns = ['LSTM - ETH base Variables']
b = b.join(c)

# %%
model_param.sort_values('MAPE', ascending=True)
# Out:
#                                                model        MSE    RMSE  \
# 11        RF Grid Search - No lags and ETH Variables    1844.57   42.95
# 9         Random Forest - No lags with ETH Variables    1900.94   43.60
# 10       Random Forest - With lags and ETH Variables    2266.30   47.61
# 18                         LSTM - ETH base Variables    3737.33   61.13
# 17      RF Grid Search - 1 lag with ETH FE Variables    5281.23   72.67
# 12                 LSTM - 1 variable and 1 look back    5554.82   74.53
# 16                 RF Grid Search - ETH FE Variables    6236.38   78.97
# 6       Random Forest - 7 lags with BTC FE Variables   10385.19  101.91
# 5                  Random Forest - 1 lag, No Ext Var   11003.63  104.90
# 14                           LSTM - BTC FE variables   18038.48  134.31
# 13                 LSTM - 1 variable and 7 look back   28790.71  169.68
# 15                           LSTM - ETH FE Variables   30923.60  175.85
# 2                                             SARIMA  154234.99  392.73
# 1                                              ARIMA  177127.00  420.86
# 0                                               ARMA  177127.00  420.86
# 3                                 SARIMAX - BTC Data  246822.36  496.81
# 7      Random Forest - No lags with BTC FE Variables  326800.32  571.66
# 4         SARIMAX - BTC data along with FE variables  309598.02  556.42
# 8   Random Forest - No lags with BTC SC FE Variables  418518.24  646.93
#
#     R-Squared   MAPE
# 11       0.96   2.11
# 9        0.96   2.15
# 10       0.94   2.31
# 18       0.92   3.03
# 17       0.88   3.52
# 12       0.87   3.52
# 16       0.86   3.75
# 6        0.70   5.28
# 5        0.75   5.32
# 14       0.60   7.69
# 13       0.18   8.75
# 15       0.31   9.44
# 2       -2.42  20.37
# 1       -2.93  22.48
# 0       -2.93  22.48
# 3       -4.48  28.44
# 7       -6.25  29.61
# 4       -5.87  31.86
# 8       -8.29  34.85

# %%
b.dropna(inplace=True)
b
# Out:
#                    ARMA        Close       SARIMA  SARIMAX - BTC Data  \
# 2022-07-13  1145.985114  1113.587158  1145.786144         1144.062597
# 2022-07-14  1147.289020  1191.526245  1161.266502         1164.271900
# 2022-07-15  1147.790816  1233.129150  1174.338793         1179.196738
# 2022-07-16  1148.926369  1352.626465  1176.736456         1182.034726
# 2022-07-17  1149.563235  1338.635742  1181.409948         1136.529820
# ...                 ...          ...          ...                 ...
# 2022-09-23  1209.464056  1328.259521  1254.330973          925.664447
# 2022-09-24  1210.366347  1317.993286  1260.346947          904.072942
# 2022-09-25  1211.269311  1294.216797  1258.757742          878.237431
# 2022-09-26  1212.172949  1335.320190  1246.220160          894.906142
# 2022-09-27  1213.077261  1330.127686  1243.393202          893.764557
#
#             SARIMAX - BTC FE Data  Random Forest - 1 lag, No Ext Var  \
# 2022-07-13            1149.477625                        1064.716991
# 2022-07-14            1171.847282                        1124.608450
# 2022-07-15            1190.676296                        1169.431675
# 2022-07-16            1196.950403                        1166.451199
# 2022-07-17            1143.588308                        1275.776668
# ...                           ...                                ...
# 2022-09-23             858.196937                        1357.270963
# 2022-09-24             832.203356                        1357.270963
# 2022-09-25             804.625315                        1348.943479
# 2022-09-26             830.120609                        1152.882938
# 2022-09-27             835.527709                        1367.456852
#
#             Random Forest - 7 lags with BTC FE Variables  \
# 2022-07-13                                   1120.802120
# 2022-07-14                                   1154.863288
# 2022-07-15                                   1174.197766
# 2022-07-16                                   1198.174449
# 2022-07-17                                   1203.015654
# ...                                                  ...
# 2022-09-23                                   1242.687281
# 2022-09-24                                   1187.286681
# 2022-09-25                                   1187.229255
# 2022-09-26                                   1221.661422
# 2022-09-27                                   1236.075615
#
#             Random Forest - No lags with BTC FE Variables  \
# 2022-07-13                                    1226.813519
# 2022-07-14                                    1232.937792
# 2022-07-15                                    1266.037397
# 2022-07-16                                    1286.725991
# 2022-07-17                                    1196.714680
# ...                                                   ...
# 2022-09-23                                    1124.425223
# 2022-09-24                                    1126.245621
# 2022-09-25                                    1030.489398
# 2022-09-26                                    1139.523993
# 2022-09-27                                    1126.245621
#
#             Random Forest - No lags with BTC SC FE Variables  \
# 2022-07-13                                       1146.268599
# 2022-07-14                                       1050.793998
# 2022-07-15                                        811.105257
# 2022-07-16                                        822.142924
# 2022-07-17                                        809.443799
# ...                                                      ...
# 2022-09-23                                       1104.554622
# 2022-09-24                                       1113.017162
# 2022-09-25                                        639.320146
# 2022-09-26                                       1128.330301
# 2022-09-27                                       1121.158749
#
#             Random Forest - No lags with ETH Variables  \
# 2022-07-13                                 1084.229214
# 2022-07-14                                 1167.459523
# 2022-07-15                                 1229.545265
# 2022-07-16                                 1252.566841
# 2022-07-17                                 1308.093121
# ...                                                ...
# 2022-09-23                                 1325.755497
# 2022-09-24                                 1293.328178
# 2022-09-25                                 1313.890104
# 2022-09-26                                 1309.259947
# 2022-09-27                                 1336.569675
#
#             Random Forest - With lags and ETH Variables  \
# 2022-07-13                                  1084.583888
# 2022-07-14                                  1188.064443
# 2022-07-15                                  1230.634446
# 2022-07-16                                  1264.656986
# 2022-07-17                                  1333.244634
# ...                                                 ...
# 2022-09-23                                  1357.416579
# 2022-09-24                                  1347.289728
# 2022-09-25                                  1356.238214
# 2022-09-26                                  1353.300214
# 2022-09-27                                  1358.966290
#
#             RF Grid Search - No lags and ETH Variables  \
# 2022-07-13                                 1085.683064
# 2022-07-14                                 1151.911240
# 2022-07-15                                 1232.981624
# 2022-07-16                                 1264.194772
# 2022-07-17                                 1330.469999
# ...                                                ...
# 2022-09-23                                 1317.442580
# 2022-09-24                                 1318.781990
# 2022-09-25                                 1317.442580
# 2022-09-26                                 1315.037854
# 2022-09-27                                 1361.894945
#
#             LSTM - 1 variable and 1 look back  \
# 2022-07-13                        1085.683064
# 2022-07-14                        1151.911240
# 2022-07-15                        1232.981624
# 2022-07-16                        1264.194772
# 2022-07-17                        1330.469999
# ...                                       ...
# 2022-09-23                        1317.442580
# 2022-09-24                        1318.781990
# 2022-09-25                        1317.442580
# 2022-09-26                        1315.037854
# 2022-09-27                        1361.894945
#
#             LSTM - 1 variable and 7 look back  LSTM - BTC FE variables  \
# 2022-07-13                        1181.343994              1428.308472
# 2022-07-14                        1173.829346              1387.853516
# 2022-07-15                        1147.135864              1380.498413
# 2022-07-16                        1123.426758              1383.775146
# 2022-07-17                        1097.206909              1307.205933
# ...                                       ...                      ...
# 2022-09-23                        1363.681519              1374.395264
# 2022-09-24                        1345.024536              1226.448975
# 2022-09-25                        1303.060913              1251.800659
# 2022-09-26                        1294.930420              1218.397339
# 2022-09-27                        1277.290161              1227.880493
#
#             LSTM - ETH FE Variables  RF Grid Search - ETH FE Variables  \
# 2022-07-13              1027.368774                        1057.115329
# 2022-07-14              1119.388184                        1157.918657
# 2022-07-15              1058.469727                        1201.553127
# 2022-07-16              1067.716919                        1240.678550
# 2022-07-17              1201.999756                        1329.262065
# ...                             ...                                ...
# 2022-09-23              1249.630859                        1316.761351
# 2022-09-24              1231.023071                        1308.907745
# 2022-09-25              1281.149902                        1297.235254
# 2022-09-26              1253.832764                        1247.889392
# 2022-09-27              1223.850830                        1310.317436
#
#             RF Grid Search - 1 lag with ETH FE Variables  \
# 2022-07-13                                   1108.650797
# 2022-07-14                                   1199.805771
# 2022-07-15                                   1286.206507
# 2022-07-16                                   1310.287962
# 2022-07-17                                   1372.442664
# ...                                                  ...
# 2022-09-23                                   1338.163580
# 2022-09-24                                   1285.512007
# 2022-09-25                                   1272.693222
# 2022-09-26                                   1180.178293
# 2022-09-27                                   1273.770983
#
#             LSTM - ETH base Variables
# 2022-07-13                1135.112549
# 2022-07-14                1222.918579
# 2022-07-15                1261.748413
# 2022-07-16                1318.882812
# 2022-07-17                1531.050537
# ...                               ...
# 2022-09-23                1268.150146
# 2022-09-24                1247.649292
# 2022-09-25                1267.793091
# 2022-09-26                1348.899414
# 2022-09-27                1366.947632
#
# [77 rows x 19 columns]

# %%
b.to_excel('C://Users//nikhi//Desktop//Nikhil//MSC LJMU//Cryptocurrency//Output//eth-outputs.xlsx')
